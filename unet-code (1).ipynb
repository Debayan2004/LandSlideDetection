# %%
# !kaggle datasets download -d tekbahadurkshetri/landslide4sense
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.6.17 / client 1.6.14)
# Dataset URL: https://www.kaggle.com/datasets/tekbahadurkshetri/landslide4sense
# License(s): other
# Downloading landslide4sense.zip to /kaggle/working
# 100%|██████████████████████████████████████▉| 2.84G/2.85G [00:27<00:00, 115MB/s]
# 100%|███████████████████████████████████████| 2.85G/2.85G [00:27<00:00, 110MB/s]

# %%
import zipfile
import os

def unzip_file(zip_filepath, dest_dir):
    """
    Unzips a .zip file to the specified destination directory.

    Parameters:
    zip_filepath (str): The path to the .zip file.
    dest_dir (str): The directory where the contents will be extracted.
    """
    # Ensure the destination directory exists
    os.makedirs(dest_dir, exist_ok=True)

    # Open the zip file
    with zipfile.ZipFile(zip_filepath, 'r') as zip_ref:
        # Extract all the contents to the destination directory
        zip_ref.extractall(dest_dir)
    print(f"Unzipped {zip_filepath} to {dest_dir}")

# Example usage
zip_filepath = '/kaggle/working/landslide4sense.zip'
dest_dir = '/kaggle/working'
unzip_file(zip_filepath, dest_dir)
# Out:
# Unzipped /kaggle/working/landslide4sense.zip to /kaggle/working

# %%
import pandas as pd
import numpy as np
import h5py
import glob
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Testing the dataset
path_single = r"/kaggle/working/TrainData/img/image_2000.h5"
path_single_mask = r'/kaggle/working/TrainData/mask/mask_2000.h5'

# %%
path_single = r"/kaggle/working/TrainData/img/image_10.h5"
path_single_mask = r'/kaggle/working/TrainData/mask/mask_1.h5'
TRAIN_PATH = r"/kaggle/working/TrainData/img/*.h5"
TRAIN_MASK = r'/kaggle/working/TrainData/mask/*.h5'

TRAIN_XX = np.zeros((3799, 128, 128, 6))
TRAIN_YY = np.zeros((3799, 128, 128, 1))
all_train = sorted(glob.glob(TRAIN_PATH))
all_mask = sorted(glob.glob(TRAIN_MASK))

# %%
for i, (img, mask) in enumerate(zip(all_train, all_mask)):
    print(i, img, mask)
    with h5py.File(img) as hdf:
        ls = list(hdf.keys())
        data = np.array(hdf.get('img'))

        # assign 0 for the nan value
        data[np.isnan(data)] = 0.000001

        # to normalize the data
        mid_rgb = data[:, :, 1:4].max() / 2.0
        mid_slope = data[:, :, 12].max() / 2.0
        mid_elevation = data[:, :, 13].max() / 2.0

        # ndvi calculation
        data_red = data[:, :, 3]
        data_nir = data[:, :, 7]
        data_ndvi = np.divide(data_nir - data_red,np.add(data_nir, data_red))

        # final array
        TRAIN_XX[i, :, :, 0] = 1 - data[:, :, 3] / mid_rgb  #RED
        TRAIN_XX[i, :, :, 1] = 1 - data[:, :, 2] / mid_rgb #GREEN
        TRAIN_XX[i, :, :, 2] = 1 - data[:, :, 1] / mid_rgb #BLUE
        TRAIN_XX[i, :, :, 3] = data_ndvi #NDVI
        TRAIN_XX[i, :, :, 4] = 1 - data[:, :, 12] / mid_slope #SLOPE
        TRAIN_XX[i, :, :, 5] = 1 - data[:, :, 13] / mid_elevation #ELEVATION


    with h5py.File(mask) as hdf:
        ls = list(hdf.keys())
        data=np.array(hdf.get('mask'))
        TRAIN_YY[i, :, :, 0] = data
# Out:
# 0 /kaggle/working/TrainData/img/image_1.h5 /kaggle/working/TrainData/mask/mask_1.h5
# 1 /kaggle/working/TrainData/img/image_10.h5 /kaggle/working/TrainData/mask/mask_10.h5
# 2 /kaggle/working/TrainData/img/image_100.h5 /kaggle/working/TrainData/mask/mask_100.h5
# 3 /kaggle/working/TrainData/img/image_1000.h5 /kaggle/working/TrainData/mask/mask_1000.h5
# 4 /kaggle/working/TrainData/img/image_1001.h5 /kaggle/working/TrainData/mask/mask_1001.h5
# 5 /kaggle/working/TrainData/img/image_1002.h5 /kaggle/working/TrainData/mask/mask_1002.h5
# 6 /kaggle/working/TrainData/img/image_1003.h5 /kaggle/working/TrainData/mask/mask_1003.h5
# 7 /kaggle/working/TrainData/img/image_1004.h5 /kaggle/working/TrainData/mask/mask_1004.h5
# 8 /kaggle/working/TrainData/img/image_1005.h5 /kaggle/working/TrainData/mask/mask_1005.h5
# 9 /kaggle/working/TrainData/img/image_1006.h5 /kaggle/working/TrainData/mask/mask_1006.h5
# 10 /kaggle/working/TrainData/img/image_1007.h5 /kaggle/working/TrainData/mask/mask_1007.h5
# 11 /kaggle/working/TrainData/img/image_1008.h5 /kaggle/working/TrainData/mask/mask_1008.h5
# 12 /kaggle/working/TrainData/img/image_1009.h5 /kaggle/working/TrainData/mask/mask_1009.h5
# 13 /kaggle/working/TrainData/img/image_101.h5 /kaggle/working/TrainData/mask/mask_101.h5
# 14 /kaggle/working/TrainData/img/image_1010.h5 /kaggle/working/TrainData/mask/mask_1010.h5
# 15 /kaggle/working/TrainData/img/image_1011.h5 /kaggle/working/TrainData/mask/mask_1011.h5
# 16 /kaggle/working/TrainData/img/image_1012.h5 /kaggle/working/TrainData/mask/mask_1012.h5
# 17 /kaggle/working/TrainData/img/image_1013.h5 /kaggle/working/TrainData/mask/mask_1013.h5
# 18 /kaggle/working/TrainData/img/image_1014.h5 /kaggle/working/TrainData/mask/mask_1014.h5
# 19 /kaggle/working/TrainData/img/image_1015.h5 /kaggle/working/TrainData/mask/mask_1015.h5
# 20 /kaggle/working/TrainData/img/image_1016.h5 /kaggle/working/TrainData/mask/mask_1016.h5
# 21 /kaggle/working/TrainData/img/image_1017.h5 /kaggle/working/TrainData/mask/mask_1017.h5
# 22 /kaggle/working/TrainData/img/image_1018.h5 /kaggle/working/TrainData/mask/mask_1018.h5
# 23 /kaggle/working/TrainData/img/image_1019.h5 /kaggle/working/TrainData/mask/mask_1019.h5
# 24 /kaggle/working/TrainData/img/image_102.h5 /kaggle/working/TrainData/mask/mask_102.h5
# 25 /kaggle/working/TrainData/img/image_1020.h5 /kaggle/working/TrainData/mask/mask_1020.h5
# 26 /kaggle/working/TrainData/img/image_1021.h5 /kaggle/working/TrainData/mask/mask_1021.h5
# 27 /kaggle/working/TrainData/img/image_1022.h5 /kaggle/working/TrainData/mask/mask_1022.h5
# 28 /kaggle/working/TrainData/img/image_1023.h5 /kaggle/working/TrainData/mask/mask_1023.h5
# 29 /kaggle/working/TrainData/img/image_1024.h5 /kaggle/working/TrainData/mask/mask_1024.h5
# 30 /kaggle/working/TrainData/img/image_1025.h5 /kaggle/working/TrainData/mask/mask_1025.h5
# 31 /kaggle/working/TrainData/img/image_1026.h5 /kaggle/working/TrainData/mask/mask_1026.h5
# 32 /kaggle/working/TrainData/img/image_1027.h5 /kaggle/working/TrainData/mask/mask_1027.h5
# 33 /kaggle/working/TrainData/img/image_1028.h5 /kaggle/working/TrainData/mask/mask_1028.h5
# 34 /kaggle/working/TrainData/img/image_1029.h5 /kaggle/working/TrainData/mask/mask_1029.h5
# 35 /kaggle/working/TrainData/img/image_103.h5 /kaggle/working/TrainData/mask/mask_103.h5
# 36 /kaggle/working/TrainData/img/image_1030.h5 /kaggle/working/TrainData/mask/mask_1030.h5
# 37 /kaggle/working/TrainData/img/image_1031.h5 /kaggle/working/TrainData/mask/mask_1031.h5
# 38 /kaggle/working/TrainData/img/image_1032.h5 /kaggle/working/TrainData/mask/mask_1032.h5
# 39 /kaggle/working/TrainData/img/image_1033.h5 /kaggle/working/TrainData/mask/mask_1033.h5
# 40 /kaggle/working/TrainData/img/image_1034.h5 /kaggle/working/TrainData/mask/mask_1034.h5
# 41 /kaggle/working/TrainData/img/image_1035.h5 /kaggle/working/TrainData/mask/mask_1035.h5
# 42 /kaggle/working/TrainData/img/image_1036.h5 /kaggle/working/TrainData/mask/mask_1036.h5
# 43 /kaggle/working/TrainData/img/image_1037.h5 /kaggle/working/TrainData/mask/mask_1037.h5
# 44 /kaggle/working/TrainData/img/image_1038.h5 /kaggle/working/TrainData/mask/mask_1038.h5
# 45 /kaggle/working/TrainData/img/image_1039.h5 /kaggle/working/TrainData/mask/mask_1039.h5
# 46 /kaggle/working/TrainData/img/image_104.h5 /kaggle/working/TrainData/mask/mask_104.h5
# 47 /kaggle/working/TrainData/img/image_1040.h5 /kaggle/working/TrainData/mask/mask_1040.h5
# 48 /kaggle/working/TrainData/img/image_1041.h5 /kaggle/working/TrainData/mask/mask_1041.h5
# 49 /kaggle/working/TrainData/img/image_1042.h5 /kaggle/working/TrainData/mask/mask_1042.h5
# 50 /kaggle/working/TrainData/img/image_1043.h5 /kaggle/working/TrainData/mask/mask_1043.h5
# 51 /kaggle/working/TrainData/img/image_1044.h5 /kaggle/working/TrainData/mask/mask_1044.h5
# 52 /kaggle/working/TrainData/img/image_1045.h5 /kaggle/working/TrainData/mask/mask_1045.h5
# 53 /kaggle/working/TrainData/img/image_1046.h5 /kaggle/working/TrainData/mask/mask_1046.h5
# 54 /kaggle/working/TrainData/img/image_1047.h5 /kaggle/working/TrainData/mask/mask_1047.h5
# 55 /kaggle/working/TrainData/img/image_1048.h5 /kaggle/working/TrainData/mask/mask_1048.h5
# 56 /kaggle/working/TrainData/img/image_1049.h5 /kaggle/working/TrainData/mask/mask_1049.h5
# 57 /kaggle/working/TrainData/img/image_105.h5 /kaggle/working/TrainData/mask/mask_105.h5
# 58 /kaggle/working/TrainData/img/image_1050.h5 /kaggle/working/TrainData/mask/mask_1050.h5
# 59 /kaggle/working/TrainData/img/image_1051.h5 /kaggle/working/TrainData/mask/mask_1051.h5
# 60 /kaggle/working/TrainData/img/image_1052.h5 /kaggle/working/TrainData/mask/mask_1052.h5
# 61 /kaggle/working/TrainData/img/image_1053.h5 /kaggle/working/TrainData/mask/mask_1053.h5
# 62 /kaggle/working/TrainData/img/image_1054.h5 /kaggle/working/TrainData/mask/mask_1054.h5
# 63 /kaggle/working/TrainData/img/image_1055.h5 /kaggle/working/TrainData/mask/mask_1055.h5
# 64 /kaggle/working/TrainData/img/image_1056.h5 /kaggle/working/TrainData/mask/mask_1056.h5
# 65 /kaggle/working/TrainData/img/image_1057.h5 /kaggle/working/TrainData/mask/mask_1057.h5
# 66 /kaggle/working/TrainData/img/image_1058.h5 /kaggle/working/TrainData/mask/mask_1058.h5
# 67 /kaggle/working/TrainData/img/image_1059.h5 /kaggle/working/TrainData/mask/mask_1059.h5
# 68 /kaggle/working/TrainData/img/image_106.h5 /kaggle/working/TrainData/mask/mask_106.h5
# 69 /kaggle/working/TrainData/img/image_1060.h5 /kaggle/working/TrainData/mask/mask_1060.h5
# 70 /kaggle/working/TrainData/img/image_1061.h5 /kaggle/working/TrainData/mask/mask_1061.h5
# 71 /kaggle/working/TrainData/img/image_1062.h5 /kaggle/working/TrainData/mask/mask_1062.h5
# 72 /kaggle/working/TrainData/img/image_1063.h5 /kaggle/working/TrainData/mask/mask_1063.h5
# 73 /kaggle/working/TrainData/img/image_1064.h5 /kaggle/working/TrainData/mask/mask_1064.h5
# 74 /kaggle/working/TrainData/img/image_1065.h5 /kaggle/working/TrainData/mask/mask_1065.h5
# 75 /kaggle/working/TrainData/img/image_1066.h5 /kaggle/working/TrainData/mask/mask_1066.h5
# 76 /kaggle/working/TrainData/img/image_1067.h5 /kaggle/working/TrainData/mask/mask_1067.h5
# 77 /kaggle/working/TrainData/img/image_1068.h5 /kaggle/working/TrainData/mask/mask_1068.h5
# 78 /kaggle/working/TrainData/img/image_1069.h5 /kaggle/working/TrainData/mask/mask_1069.h5
# 79 /kaggle/working/TrainData/img/image_107.h5 /kaggle/working/TrainData/mask/mask_107.h5
# 80 /kaggle/working/TrainData/img/image_1070.h5 /kaggle/working/TrainData/mask/mask_1070.h5
# 81 /kaggle/working/TrainData/img/image_1071.h5 /kaggle/working/TrainData/mask/mask_1071.h5
# 82 /kaggle/working/TrainData/img/image_1072.h5 /kaggle/working/TrainData/mask/mask_1072.h5
# 83 /kaggle/working/TrainData/img/image_1073.h5 /kaggle/working/TrainData/mask/mask_1073.h5
# 84 /kaggle/working/TrainData/img/image_1074.h5 /kaggle/working/TrainData/mask/mask_1074.h5
# 85 /kaggle/working/TrainData/img/image_1075.h5 /kaggle/working/TrainData/mask/mask_1075.h5
# 86 /kaggle/working/TrainData/img/image_1076.h5 /kaggle/working/TrainData/mask/mask_1076.h5
# 87 /kaggle/working/TrainData/img/image_1077.h5 /kaggle/working/TrainData/mask/mask_1077.h5
# 88 /kaggle/working/TrainData/img/image_1078.h5 /kaggle/working/TrainData/mask/mask_1078.h5
# 89 /kaggle/working/TrainData/img/image_1079.h5 /kaggle/working/TrainData/mask/mask_1079.h5
# 90 /kaggle/working/TrainData/img/image_108.h5 /kaggle/working/TrainData/mask/mask_108.h5
# 91 /kaggle/working/TrainData/img/image_1080.h5 /kaggle/working/TrainData/mask/mask_1080.h5
# 92 /kaggle/working/TrainData/img/image_1081.h5 /kaggle/working/TrainData/mask/mask_1081.h5
# 93 /kaggle/working/TrainData/img/image_1082.h5 /kaggle/working/TrainData/mask/mask_1082.h5
# 94 /kaggle/working/TrainData/img/image_1083.h5 /kaggle/working/TrainData/mask/mask_1083.h5
# 95 /kaggle/working/TrainData/img/image_1084.h5 /kaggle/working/TrainData/mask/mask_1084.h5
# 96 /kaggle/working/TrainData/img/image_1085.h5 /kaggle/working/TrainData/mask/mask_1085.h5
# 97 /kaggle/working/TrainData/img/image_1086.h5 /kaggle/working/TrainData/mask/mask_1086.h5
# 98 /kaggle/working/TrainData/img/image_1087.h5 /kaggle/working/TrainData/mask/mask_1087.h5
# 99 /kaggle/working/TrainData/img/image_1088.h5 /kaggle/working/TrainData/mask/mask_1088.h5
# 100 /kaggle/working/TrainData/img/image_1089.h5 /kaggle/working/TrainData/mask/mask_1089.h5
# 101 /kaggle/working/TrainData/img/image_109.h5 /kaggle/working/TrainData/mask/mask_109.h5
# 102 /kaggle/working/TrainData/img/image_1090.h5 /kaggle/working/TrainData/mask/mask_1090.h5
# 103 /kaggle/working/TrainData/img/image_1091.h5 /kaggle/working/TrainData/mask/mask_1091.h5
# 104 /kaggle/working/TrainData/img/image_1092.h5 /kaggle/working/TrainData/mask/mask_1092.h5
# 105 /kaggle/working/TrainData/img/image_1093.h5 /kaggle/working/TrainData/mask/mask_1093.h5
# 106 /kaggle/working/TrainData/img/image_1094.h5 /kaggle/working/TrainData/mask/mask_1094.h5
# 107 /kaggle/working/TrainData/img/image_1095.h5 /kaggle/working/TrainData/mask/mask_1095.h5
# 108 /kaggle/working/TrainData/img/image_1096.h5 /kaggle/working/TrainData/mask/mask_1096.h5
# 109 /kaggle/working/TrainData/img/image_1097.h5 /kaggle/working/TrainData/mask/mask_1097.h5
# 110 /kaggle/working/TrainData/img/image_1098.h5 /kaggle/working/TrainData/mask/mask_1098.h5
# 111 /kaggle/working/TrainData/img/image_1099.h5 /kaggle/working/TrainData/mask/mask_1099.h5
# 112 /kaggle/working/TrainData/img/image_11.h5 /kaggle/working/TrainData/mask/mask_11.h5
# 113 /kaggle/working/TrainData/img/image_110.h5 /kaggle/working/TrainData/mask/mask_110.h5
# 114 /kaggle/working/TrainData/img/image_1100.h5 /kaggle/working/TrainData/mask/mask_1100.h5
# 115 /kaggle/working/TrainData/img/image_1101.h5 /kaggle/working/TrainData/mask/mask_1101.h5
# 116 /kaggle/working/TrainData/img/image_1102.h5 /kaggle/working/TrainData/mask/mask_1102.h5
# 117 /kaggle/working/TrainData/img/image_1103.h5 /kaggle/working/TrainData/mask/mask_1103.h5
# 118 /kaggle/working/TrainData/img/image_1104.h5 /kaggle/working/TrainData/mask/mask_1104.h5
# 119 /kaggle/working/TrainData/img/image_1105.h5 /kaggle/working/TrainData/mask/mask_1105.h5
# 120 /kaggle/working/TrainData/img/image_1106.h5 /kaggle/working/TrainData/mask/mask_1106.h5
# 121 /kaggle/working/TrainData/img/image_1107.h5 /kaggle/working/TrainData/mask/mask_1107.h5
# 122 /kaggle/working/TrainData/img/image_1108.h5 /kaggle/working/TrainData/mask/mask_1108.h5
# 123 /kaggle/working/TrainData/img/image_1109.h5 /kaggle/working/TrainData/mask/mask_1109.h5
# 124 /kaggle/working/TrainData/img/image_111.h5 /kaggle/working/TrainData/mask/mask_111.h5
# 125 /kaggle/working/TrainData/img/image_1110.h5 /kaggle/working/TrainData/mask/mask_1110.h5
# 126 /kaggle/working/TrainData/img/image_1111.h5 /kaggle/working/TrainData/mask/mask_1111.h5
# 127 /kaggle/working/TrainData/img/image_1112.h5 /kaggle/working/TrainData/mask/mask_1112.h5
# 128 /kaggle/working/TrainData/img/image_1113.h5 /kaggle/working/TrainData/mask/mask_1113.h5
# 129 /kaggle/working/TrainData/img/image_1114.h5 /kaggle/working/TrainData/mask/mask_1114.h5
# 130 /kaggle/working/TrainData/img/image_1115.h5 /kaggle/working/TrainData/mask/mask_1115.h5
# 131 /kaggle/working/TrainData/img/image_1116.h5 /kaggle/working/TrainData/mask/mask_1116.h5
# 132 /kaggle/working/TrainData/img/image_1117.h5 /kaggle/working/TrainData/mask/mask_1117.h5
# 133 /kaggle/working/TrainData/img/image_1118.h5 /kaggle/working/TrainData/mask/mask_1118.h5
# 134 /kaggle/working/TrainData/img/image_1119.h5 /kaggle/working/TrainData/mask/mask_1119.h5
# 135 /kaggle/working/TrainData/img/image_112.h5 /kaggle/working/TrainData/mask/mask_112.h5
# 136 /kaggle/working/TrainData/img/image_1120.h5 /kaggle/working/TrainData/mask/mask_1120.h5
# 137 /kaggle/working/TrainData/img/image_1121.h5 /kaggle/working/TrainData/mask/mask_1121.h5
# 138 /kaggle/working/TrainData/img/image_1122.h5 /kaggle/working/TrainData/mask/mask_1122.h5
# 139 /kaggle/working/TrainData/img/image_1123.h5 /kaggle/working/TrainData/mask/mask_1123.h5
# 140 /kaggle/working/TrainData/img/image_1124.h5 /kaggle/working/TrainData/mask/mask_1124.h5
# 141 /kaggle/working/TrainData/img/image_1125.h5 /kaggle/working/TrainData/mask/mask_1125.h5
# 142 /kaggle/working/TrainData/img/image_1126.h5 /kaggle/working/TrainData/mask/mask_1126.h5
# 143 /kaggle/working/TrainData/img/image_1127.h5 /kaggle/working/TrainData/mask/mask_1127.h5
# 144 /kaggle/working/TrainData/img/image_1128.h5 /kaggle/working/TrainData/mask/mask_1128.h5
# 145 /kaggle/working/TrainData/img/image_1129.h5 /kaggle/working/TrainData/mask/mask_1129.h5
# 146 /kaggle/working/TrainData/img/image_113.h5 /kaggle/working/TrainData/mask/mask_113.h5
# 147 /kaggle/working/TrainData/img/image_1130.h5 /kaggle/working/TrainData/mask/mask_1130.h5
# 148 /kaggle/working/TrainData/img/image_1131.h5 /kaggle/working/TrainData/mask/mask_1131.h5
# 149 /kaggle/working/TrainData/img/image_1132.h5 /kaggle/working/TrainData/mask/mask_1132.h5
# 150 /kaggle/working/TrainData/img/image_1133.h5 /kaggle/working/TrainData/mask/mask_1133.h5
# 151 /kaggle/working/TrainData/img/image_1134.h5 /kaggle/working/TrainData/mask/mask_1134.h5
# 152 /kaggle/working/TrainData/img/image_1135.h5 /kaggle/working/TrainData/mask/mask_1135.h5
# 153 /kaggle/working/TrainData/img/image_1136.h5 /kaggle/working/TrainData/mask/mask_1136.h5
# 154 /kaggle/working/TrainData/img/image_1137.h5 /kaggle/working/TrainData/mask/mask_1137.h5
# 155 /kaggle/working/TrainData/img/image_1138.h5 /kaggle/working/TrainData/mask/mask_1138.h5
# 156 /kaggle/working/TrainData/img/image_1139.h5 /kaggle/working/TrainData/mask/mask_1139.h5
# 157 /kaggle/working/TrainData/img/image_114.h5 /kaggle/working/TrainData/mask/mask_114.h5
# 158 /kaggle/working/TrainData/img/image_1140.h5 /kaggle/working/TrainData/mask/mask_1140.h5
# 159 /kaggle/working/TrainData/img/image_1141.h5 /kaggle/working/TrainData/mask/mask_1141.h5
# 160 /kaggle/working/TrainData/img/image_1142.h5 /kaggle/working/TrainData/mask/mask_1142.h5
# 161 /kaggle/working/TrainData/img/image_1143.h5 /kaggle/working/TrainData/mask/mask_1143.h5
# 162 /kaggle/working/TrainData/img/image_1144.h5 /kaggle/working/TrainData/mask/mask_1144.h5
# 163 /kaggle/working/TrainData/img/image_1145.h5 /kaggle/working/TrainData/mask/mask_1145.h5
# 164 /kaggle/working/TrainData/img/image_1146.h5 /kaggle/working/TrainData/mask/mask_1146.h5
# 165 /kaggle/working/TrainData/img/image_1147.h5 /kaggle/working/TrainData/mask/mask_1147.h5
# 166 /kaggle/working/TrainData/img/image_1148.h5 /kaggle/working/TrainData/mask/mask_1148.h5
# 167 /kaggle/working/TrainData/img/image_1149.h5 /kaggle/working/TrainData/mask/mask_1149.h5
# 168 /kaggle/working/TrainData/img/image_115.h5 /kaggle/working/TrainData/mask/mask_115.h5
# 169 /kaggle/working/TrainData/img/image_1150.h5 /kaggle/working/TrainData/mask/mask_1150.h5
# 170 /kaggle/working/TrainData/img/image_1151.h5 /kaggle/working/TrainData/mask/mask_1151.h5
# 171 /kaggle/working/TrainData/img/image_1152.h5 /kaggle/working/TrainData/mask/mask_1152.h5
# 172 /kaggle/working/TrainData/img/image_1153.h5 /kaggle/working/TrainData/mask/mask_1153.h5
# 173 /kaggle/working/TrainData/img/image_1154.h5 /kaggle/working/TrainData/mask/mask_1154.h5
# 174 /kaggle/working/TrainData/img/image_1155.h5 /kaggle/working/TrainData/mask/mask_1155.h5
# 175 /kaggle/working/TrainData/img/image_1156.h5 /kaggle/working/TrainData/mask/mask_1156.h5
# 176 /kaggle/working/TrainData/img/image_1157.h5 /kaggle/working/TrainData/mask/mask_1157.h5
# 177 /kaggle/working/TrainData/img/image_1158.h5 /kaggle/working/TrainData/mask/mask_1158.h5
# 178 /kaggle/working/TrainData/img/image_1159.h5 /kaggle/working/TrainData/mask/mask_1159.h5
# 179 /kaggle/working/TrainData/img/image_116.h5 /kaggle/working/TrainData/mask/mask_116.h5
# 180 /kaggle/working/TrainData/img/image_1160.h5 /kaggle/working/TrainData/mask/mask_1160.h5
# 181 /kaggle/working/TrainData/img/image_1161.h5 /kaggle/working/TrainData/mask/mask_1161.h5
# 182 /kaggle/working/TrainData/img/image_1162.h5 /kaggle/working/TrainData/mask/mask_1162.h5
# 183 /kaggle/working/TrainData/img/image_1163.h5 /kaggle/working/TrainData/mask/mask_1163.h5
# 184 /kaggle/working/TrainData/img/image_1164.h5 /kaggle/working/TrainData/mask/mask_1164.h5
# 185 /kaggle/working/TrainData/img/image_1165.h5 /kaggle/working/TrainData/mask/mask_1165.h5
# 186 /kaggle/working/TrainData/img/image_1166.h5 /kaggle/working/TrainData/mask/mask_1166.h5
# 187 /kaggle/working/TrainData/img/image_1167.h5 /kaggle/working/TrainData/mask/mask_1167.h5
# 188 /kaggle/working/TrainData/img/image_1168.h5 /kaggle/working/TrainData/mask/mask_1168.h5
# 189 /kaggle/working/TrainData/img/image_1169.h5 /kaggle/working/TrainData/mask/mask_1169.h5
# 190 /kaggle/working/TrainData/img/image_117.h5 /kaggle/working/TrainData/mask/mask_117.h5
# 191 /kaggle/working/TrainData/img/image_1170.h5 /kaggle/working/TrainData/mask/mask_1170.h5
# 192 /kaggle/working/TrainData/img/image_1171.h5 /kaggle/working/TrainData/mask/mask_1171.h5
# 193 /kaggle/working/TrainData/img/image_1172.h5 /kaggle/working/TrainData/mask/mask_1172.h5
# 194 /kaggle/working/TrainData/img/image_1173.h5 /kaggle/working/TrainData/mask/mask_1173.h5
# 195 /kaggle/working/TrainData/img/image_1174.h5 /kaggle/working/TrainData/mask/mask_1174.h5
# 196 /kaggle/working/TrainData/img/image_1175.h5 /kaggle/working/TrainData/mask/mask_1175.h5
# 197 /kaggle/working/TrainData/img/image_1176.h5 /kaggle/working/TrainData/mask/mask_1176.h5
# 198 /kaggle/working/TrainData/img/image_1177.h5 /kaggle/working/TrainData/mask/mask_1177.h5
# 199 /kaggle/working/TrainData/img/image_1178.h5 /kaggle/working/TrainData/mask/mask_1178.h5
# 200 /kaggle/working/TrainData/img/image_1179.h5 /kaggle/working/TrainData/mask/mask_1179.h5
# 201 /kaggle/working/TrainData/img/image_118.h5 /kaggle/working/TrainData/mask/mask_118.h5
# 202 /kaggle/working/TrainData/img/image_1180.h5 /kaggle/working/TrainData/mask/mask_1180.h5
# 203 /kaggle/working/TrainData/img/image_1181.h5 /kaggle/working/TrainData/mask/mask_1181.h5
# 204 /kaggle/working/TrainData/img/image_1182.h5 /kaggle/working/TrainData/mask/mask_1182.h5
# 205 /kaggle/working/TrainData/img/image_1183.h5 /kaggle/working/TrainData/mask/mask_1183.h5
# 206 /kaggle/working/TrainData/img/image_1184.h5 /kaggle/working/TrainData/mask/mask_1184.h5
# 207 /kaggle/working/TrainData/img/image_1185.h5 /kaggle/working/TrainData/mask/mask_1185.h5
# 208 /kaggle/working/TrainData/img/image_1186.h5 /kaggle/working/TrainData/mask/mask_1186.h5
# 209 /kaggle/working/TrainData/img/image_1187.h5 /kaggle/working/TrainData/mask/mask_1187.h5
# 210 /kaggle/working/TrainData/img/image_1188.h5 /kaggle/working/TrainData/mask/mask_1188.h5
# 211 /kaggle/working/TrainData/img/image_1189.h5 /kaggle/working/TrainData/mask/mask_1189.h5
# 212 /kaggle/working/TrainData/img/image_119.h5 /kaggle/working/TrainData/mask/mask_119.h5
# 213 /kaggle/working/TrainData/img/image_1190.h5 /kaggle/working/TrainData/mask/mask_1190.h5
# 214 /kaggle/working/TrainData/img/image_1191.h5 /kaggle/working/TrainData/mask/mask_1191.h5
# 215 /kaggle/working/TrainData/img/image_1192.h5 /kaggle/working/TrainData/mask/mask_1192.h5
# 216 /kaggle/working/TrainData/img/image_1193.h5 /kaggle/working/TrainData/mask/mask_1193.h5
# 217 /kaggle/working/TrainData/img/image_1194.h5 /kaggle/working/TrainData/mask/mask_1194.h5
# 218 /kaggle/working/TrainData/img/image_1195.h5 /kaggle/working/TrainData/mask/mask_1195.h5
# 219 /kaggle/working/TrainData/img/image_1196.h5 /kaggle/working/TrainData/mask/mask_1196.h5
# 220 /kaggle/working/TrainData/img/image_1197.h5 /kaggle/working/TrainData/mask/mask_1197.h5
# 221 /kaggle/working/TrainData/img/image_1198.h5 /kaggle/working/TrainData/mask/mask_1198.h5
# 222 /kaggle/working/TrainData/img/image_1199.h5 /kaggle/working/TrainData/mask/mask_1199.h5
# 223 /kaggle/working/TrainData/img/image_12.h5 /kaggle/working/TrainData/mask/mask_12.h5
# 224 /kaggle/working/TrainData/img/image_120.h5 /kaggle/working/TrainData/mask/mask_120.h5
# 225 /kaggle/working/TrainData/img/image_1200.h5 /kaggle/working/TrainData/mask/mask_1200.h5
# 226 /kaggle/working/TrainData/img/image_1201.h5 /kaggle/working/TrainData/mask/mask_1201.h5
# 227 /kaggle/working/TrainData/img/image_1202.h5 /kaggle/working/TrainData/mask/mask_1202.h5
# 228 /kaggle/working/TrainData/img/image_1203.h5 /kaggle/working/TrainData/mask/mask_1203.h5
# 229 /kaggle/working/TrainData/img/image_1204.h5 /kaggle/working/TrainData/mask/mask_1204.h5
# 230 /kaggle/working/TrainData/img/image_1205.h5 /kaggle/working/TrainData/mask/mask_1205.h5
# 231 /kaggle/working/TrainData/img/image_1206.h5 /kaggle/working/TrainData/mask/mask_1206.h5
# 232 /kaggle/working/TrainData/img/image_1207.h5 /kaggle/working/TrainData/mask/mask_1207.h5
# 233 /kaggle/working/TrainData/img/image_1208.h5 /kaggle/working/TrainData/mask/mask_1208.h5
# 234 /kaggle/working/TrainData/img/image_1209.h5 /kaggle/working/TrainData/mask/mask_1209.h5
# 235 /kaggle/working/TrainData/img/image_121.h5 /kaggle/working/TrainData/mask/mask_121.h5
# 236 /kaggle/working/TrainData/img/image_1210.h5 /kaggle/working/TrainData/mask/mask_1210.h5
# 237 /kaggle/working/TrainData/img/image_1211.h5 /kaggle/working/TrainData/mask/mask_1211.h5
# 238 /kaggle/working/TrainData/img/image_1212.h5 /kaggle/working/TrainData/mask/mask_1212.h5
# 239 /kaggle/working/TrainData/img/image_1213.h5 /kaggle/working/TrainData/mask/mask_1213.h5
# 240 /kaggle/working/TrainData/img/image_1214.h5 /kaggle/working/TrainData/mask/mask_1214.h5
# 241 /kaggle/working/TrainData/img/image_1215.h5 /kaggle/working/TrainData/mask/mask_1215.h5
# 242 /kaggle/working/TrainData/img/image_1216.h5 /kaggle/working/TrainData/mask/mask_1216.h5
# 243 /kaggle/working/TrainData/img/image_1217.h5 /kaggle/working/TrainData/mask/mask_1217.h5
# 244 /kaggle/working/TrainData/img/image_1218.h5 /kaggle/working/TrainData/mask/mask_1218.h5
# 245 /kaggle/working/TrainData/img/image_1219.h5 /kaggle/working/TrainData/mask/mask_1219.h5
# 246 /kaggle/working/TrainData/img/image_122.h5 /kaggle/working/TrainData/mask/mask_122.h5
# 247 /kaggle/working/TrainData/img/image_1220.h5 /kaggle/working/TrainData/mask/mask_1220.h5
# 248 /kaggle/working/TrainData/img/image_1221.h5 /kaggle/working/TrainData/mask/mask_1221.h5
# 249 /kaggle/working/TrainData/img/image_1222.h5 /kaggle/working/TrainData/mask/mask_1222.h5
# 250 /kaggle/working/TrainData/img/image_1223.h5 /kaggle/working/TrainData/mask/mask_1223.h5
# 251 /kaggle/working/TrainData/img/image_1224.h5 /kaggle/working/TrainData/mask/mask_1224.h5
# 252 /kaggle/working/TrainData/img/image_1225.h5 /kaggle/working/TrainData/mask/mask_1225.h5
# 253 /kaggle/working/TrainData/img/image_1226.h5 /kaggle/working/TrainData/mask/mask_1226.h5
# 254 /kaggle/working/TrainData/img/image_1227.h5 /kaggle/working/TrainData/mask/mask_1227.h5
# 255 /kaggle/working/TrainData/img/image_1228.h5 /kaggle/working/TrainData/mask/mask_1228.h5
# 256 /kaggle/working/TrainData/img/image_1229.h5 /kaggle/working/TrainData/mask/mask_1229.h5
# 257 /kaggle/working/TrainData/img/image_123.h5 /kaggle/working/TrainData/mask/mask_123.h5
# 258 /kaggle/working/TrainData/img/image_1230.h5 /kaggle/working/TrainData/mask/mask_1230.h5
# 259 /kaggle/working/TrainData/img/image_1231.h5 /kaggle/working/TrainData/mask/mask_1231.h5
# 260 /kaggle/working/TrainData/img/image_1232.h5 /kaggle/working/TrainData/mask/mask_1232.h5
# 261 /kaggle/working/TrainData/img/image_1233.h5 /kaggle/working/TrainData/mask/mask_1233.h5
# 262 /kaggle/working/TrainData/img/image_1234.h5 /kaggle/working/TrainData/mask/mask_1234.h5
# 263 /kaggle/working/TrainData/img/image_1235.h5 /kaggle/working/TrainData/mask/mask_1235.h5
# 264 /kaggle/working/TrainData/img/image_1236.h5 /kaggle/working/TrainData/mask/mask_1236.h5
# 265 /kaggle/working/TrainData/img/image_1237.h5 /kaggle/working/TrainData/mask/mask_1237.h5
# 266 /kaggle/working/TrainData/img/image_1238.h5 /kaggle/working/TrainData/mask/mask_1238.h5
# 267 /kaggle/working/TrainData/img/image_1239.h5 /kaggle/working/TrainData/mask/mask_1239.h5
# 268 /kaggle/working/TrainData/img/image_124.h5 /kaggle/working/TrainData/mask/mask_124.h5
# 269 /kaggle/working/TrainData/img/image_1240.h5 /kaggle/working/TrainData/mask/mask_1240.h5
# 270 /kaggle/working/TrainData/img/image_1241.h5 /kaggle/working/TrainData/mask/mask_1241.h5
# 271 /kaggle/working/TrainData/img/image_1242.h5 /kaggle/working/TrainData/mask/mask_1242.h5
# 272 /kaggle/working/TrainData/img/image_1243.h5 /kaggle/working/TrainData/mask/mask_1243.h5
# 273 /kaggle/working/TrainData/img/image_1244.h5 /kaggle/working/TrainData/mask/mask_1244.h5
# 274 /kaggle/working/TrainData/img/image_1245.h5 /kaggle/working/TrainData/mask/mask_1245.h5
# 275 /kaggle/working/TrainData/img/image_1246.h5 /kaggle/working/TrainData/mask/mask_1246.h5
# 276 /kaggle/working/TrainData/img/image_1247.h5 /kaggle/working/TrainData/mask/mask_1247.h5
# 277 /kaggle/working/TrainData/img/image_1248.h5 /kaggle/working/TrainData/mask/mask_1248.h5
# 278 /kaggle/working/TrainData/img/image_1249.h5 /kaggle/working/TrainData/mask/mask_1249.h5
# 279 /kaggle/working/TrainData/img/image_125.h5 /kaggle/working/TrainData/mask/mask_125.h5
# 280 /kaggle/working/TrainData/img/image_1250.h5 /kaggle/working/TrainData/mask/mask_1250.h5
# 281 /kaggle/working/TrainData/img/image_1251.h5 /kaggle/working/TrainData/mask/mask_1251.h5
# 282 /kaggle/working/TrainData/img/image_1252.h5 /kaggle/working/TrainData/mask/mask_1252.h5
# 283 /kaggle/working/TrainData/img/image_1253.h5 /kaggle/working/TrainData/mask/mask_1253.h5
# 284 /kaggle/working/TrainData/img/image_1254.h5 /kaggle/working/TrainData/mask/mask_1254.h5
# 285 /kaggle/working/TrainData/img/image_1255.h5 /kaggle/working/TrainData/mask/mask_1255.h5
# 286 /kaggle/working/TrainData/img/image_1256.h5 /kaggle/working/TrainData/mask/mask_1256.h5
# 287 /kaggle/working/TrainData/img/image_1257.h5 /kaggle/working/TrainData/mask/mask_1257.h5
# 288 /kaggle/working/TrainData/img/image_1258.h5 /kaggle/working/TrainData/mask/mask_1258.h5
# 289 /kaggle/working/TrainData/img/image_1259.h5 /kaggle/working/TrainData/mask/mask_1259.h5
# 290 /kaggle/working/TrainData/img/image_126.h5 /kaggle/working/TrainData/mask/mask_126.h5
# 291 /kaggle/working/TrainData/img/image_1260.h5 /kaggle/working/TrainData/mask/mask_1260.h5
# 292 /kaggle/working/TrainData/img/image_1261.h5 /kaggle/working/TrainData/mask/mask_1261.h5
# 293 /kaggle/working/TrainData/img/image_1262.h5 /kaggle/working/TrainData/mask/mask_1262.h5
# 294 /kaggle/working/TrainData/img/image_1263.h5 /kaggle/working/TrainData/mask/mask_1263.h5
# 295 /kaggle/working/TrainData/img/image_1264.h5 /kaggle/working/TrainData/mask/mask_1264.h5
# 296 /kaggle/working/TrainData/img/image_1265.h5 /kaggle/working/TrainData/mask/mask_1265.h5
# 297 /kaggle/working/TrainData/img/image_1266.h5 /kaggle/working/TrainData/mask/mask_1266.h5
# 298 /kaggle/working/TrainData/img/image_1267.h5 /kaggle/working/TrainData/mask/mask_1267.h5
# 299 /kaggle/working/TrainData/img/image_1268.h5 /kaggle/working/TrainData/mask/mask_1268.h5
# 300 /kaggle/working/TrainData/img/image_1269.h5 /kaggle/working/TrainData/mask/mask_1269.h5
# 301 /kaggle/working/TrainData/img/image_127.h5 /kaggle/working/TrainData/mask/mask_127.h5
# 302 /kaggle/working/TrainData/img/image_1270.h5 /kaggle/working/TrainData/mask/mask_1270.h5
# 303 /kaggle/working/TrainData/img/image_1271.h5 /kaggle/working/TrainData/mask/mask_1271.h5
# 304 /kaggle/working/TrainData/img/image_1272.h5 /kaggle/working/TrainData/mask/mask_1272.h5
# 305 /kaggle/working/TrainData/img/image_1273.h5 /kaggle/working/TrainData/mask/mask_1273.h5
# 306 /kaggle/working/TrainData/img/image_1274.h5 /kaggle/working/TrainData/mask/mask_1274.h5
# 307 /kaggle/working/TrainData/img/image_1275.h5 /kaggle/working/TrainData/mask/mask_1275.h5
# 308 /kaggle/working/TrainData/img/image_1276.h5 /kaggle/working/TrainData/mask/mask_1276.h5
# 309 /kaggle/working/TrainData/img/image_1277.h5 /kaggle/working/TrainData/mask/mask_1277.h5
# 310 /kaggle/working/TrainData/img/image_1278.h5 /kaggle/working/TrainData/mask/mask_1278.h5
# 311 /kaggle/working/TrainData/img/image_1279.h5 /kaggle/working/TrainData/mask/mask_1279.h5
# 312 /kaggle/working/TrainData/img/image_128.h5 /kaggle/working/TrainData/mask/mask_128.h5
# 313 /kaggle/working/TrainData/img/image_1280.h5 /kaggle/working/TrainData/mask/mask_1280.h5
# 314 /kaggle/working/TrainData/img/image_1281.h5 /kaggle/working/TrainData/mask/mask_1281.h5
# 315 /kaggle/working/TrainData/img/image_1282.h5 /kaggle/working/TrainData/mask/mask_1282.h5
# 316 /kaggle/working/TrainData/img/image_1283.h5 /kaggle/working/TrainData/mask/mask_1283.h5
# 317 /kaggle/working/TrainData/img/image_1284.h5 /kaggle/working/TrainData/mask/mask_1284.h5
# 318 /kaggle/working/TrainData/img/image_1285.h5 /kaggle/working/TrainData/mask/mask_1285.h5
# 319 /kaggle/working/TrainData/img/image_1286.h5 /kaggle/working/TrainData/mask/mask_1286.h5
# 320 /kaggle/working/TrainData/img/image_1287.h5 /kaggle/working/TrainData/mask/mask_1287.h5
# 321 /kaggle/working/TrainData/img/image_1288.h5 /kaggle/working/TrainData/mask/mask_1288.h5
# 322 /kaggle/working/TrainData/img/image_1289.h5 /kaggle/working/TrainData/mask/mask_1289.h5
# 323 /kaggle/working/TrainData/img/image_129.h5 /kaggle/working/TrainData/mask/mask_129.h5
# 324 /kaggle/working/TrainData/img/image_1290.h5 /kaggle/working/TrainData/mask/mask_1290.h5
# 325 /kaggle/working/TrainData/img/image_1291.h5 /kaggle/working/TrainData/mask/mask_1291.h5
# 326 /kaggle/working/TrainData/img/image_1292.h5 /kaggle/working/TrainData/mask/mask_1292.h5
# 327 /kaggle/working/TrainData/img/image_1293.h5 /kaggle/working/TrainData/mask/mask_1293.h5
# 328 /kaggle/working/TrainData/img/image_1294.h5 /kaggle/working/TrainData/mask/mask_1294.h5
# 329 /kaggle/working/TrainData/img/image_1295.h5 /kaggle/working/TrainData/mask/mask_1295.h5
# 330 /kaggle/working/TrainData/img/image_1296.h5 /kaggle/working/TrainData/mask/mask_1296.h5
# 331 /kaggle/working/TrainData/img/image_1297.h5 /kaggle/working/TrainData/mask/mask_1297.h5
# 332 /kaggle/working/TrainData/img/image_1298.h5 /kaggle/working/TrainData/mask/mask_1298.h5
# 333 /kaggle/working/TrainData/img/image_1299.h5 /kaggle/working/TrainData/mask/mask_1299.h5
# 334 /kaggle/working/TrainData/img/image_13.h5 /kaggle/working/TrainData/mask/mask_13.h5
# 335 /kaggle/working/TrainData/img/image_130.h5 /kaggle/working/TrainData/mask/mask_130.h5
# 336 /kaggle/working/TrainData/img/image_1300.h5 /kaggle/working/TrainData/mask/mask_1300.h5
# 337 /kaggle/working/TrainData/img/image_1301.h5 /kaggle/working/TrainData/mask/mask_1301.h5
# 338 /kaggle/working/TrainData/img/image_1302.h5 /kaggle/working/TrainData/mask/mask_1302.h5
# 339 /kaggle/working/TrainData/img/image_1303.h5 /kaggle/working/TrainData/mask/mask_1303.h5
# 340 /kaggle/working/TrainData/img/image_1304.h5 /kaggle/working/TrainData/mask/mask_1304.h5
# 341 /kaggle/working/TrainData/img/image_1305.h5 /kaggle/working/TrainData/mask/mask_1305.h5
# 342 /kaggle/working/TrainData/img/image_1306.h5 /kaggle/working/TrainData/mask/mask_1306.h5
# 343 /kaggle/working/TrainData/img/image_1307.h5 /kaggle/working/TrainData/mask/mask_1307.h5
# 344 /kaggle/working/TrainData/img/image_1308.h5 /kaggle/working/TrainData/mask/mask_1308.h5
# 345 /kaggle/working/TrainData/img/image_1309.h5 /kaggle/working/TrainData/mask/mask_1309.h5
# 346 /kaggle/working/TrainData/img/image_131.h5 /kaggle/working/TrainData/mask/mask_131.h5
# 347 /kaggle/working/TrainData/img/image_1310.h5 /kaggle/working/TrainData/mask/mask_1310.h5
# 348 /kaggle/working/TrainData/img/image_1311.h5 /kaggle/working/TrainData/mask/mask_1311.h5
# 349 /kaggle/working/TrainData/img/image_1312.h5 /kaggle/working/TrainData/mask/mask_1312.h5
# 350 /kaggle/working/TrainData/img/image_1313.h5 /kaggle/working/TrainData/mask/mask_1313.h5
# 351 /kaggle/working/TrainData/img/image_1314.h5 /kaggle/working/TrainData/mask/mask_1314.h5
# 352 /kaggle/working/TrainData/img/image_1315.h5 /kaggle/working/TrainData/mask/mask_1315.h5
# 353 /kaggle/working/TrainData/img/image_1316.h5 /kaggle/working/TrainData/mask/mask_1316.h5
# 354 /kaggle/working/TrainData/img/image_1317.h5 /kaggle/working/TrainData/mask/mask_1317.h5
# 355 /kaggle/working/TrainData/img/image_1318.h5 /kaggle/working/TrainData/mask/mask_1318.h5
# 356 /kaggle/working/TrainData/img/image_1319.h5 /kaggle/working/TrainData/mask/mask_1319.h5
# 357 /kaggle/working/TrainData/img/image_132.h5 /kaggle/working/TrainData/mask/mask_132.h5
# 358 /kaggle/working/TrainData/img/image_1320.h5 /kaggle/working/TrainData/mask/mask_1320.h5
# 359 /kaggle/working/TrainData/img/image_1321.h5 /kaggle/working/TrainData/mask/mask_1321.h5
# 360 /kaggle/working/TrainData/img/image_1322.h5 /kaggle/working/TrainData/mask/mask_1322.h5
# 361 /kaggle/working/TrainData/img/image_1323.h5 /kaggle/working/TrainData/mask/mask_1323.h5
# 362 /kaggle/working/TrainData/img/image_1324.h5 /kaggle/working/TrainData/mask/mask_1324.h5
# 363 /kaggle/working/TrainData/img/image_1325.h5 /kaggle/working/TrainData/mask/mask_1325.h5
# 364 /kaggle/working/TrainData/img/image_1326.h5 /kaggle/working/TrainData/mask/mask_1326.h5
# 365 /kaggle/working/TrainData/img/image_1327.h5 /kaggle/working/TrainData/mask/mask_1327.h5
# 366 /kaggle/working/TrainData/img/image_1328.h5 /kaggle/working/TrainData/mask/mask_1328.h5
# 367 /kaggle/working/TrainData/img/image_1329.h5 /kaggle/working/TrainData/mask/mask_1329.h5
# 368 /kaggle/working/TrainData/img/image_133.h5 /kaggle/working/TrainData/mask/mask_133.h5
# 369 /kaggle/working/TrainData/img/image_1330.h5 /kaggle/working/TrainData/mask/mask_1330.h5
# 370 /kaggle/working/TrainData/img/image_1331.h5 /kaggle/working/TrainData/mask/mask_1331.h5
# 371 /kaggle/working/TrainData/img/image_1332.h5 /kaggle/working/TrainData/mask/mask_1332.h5
# 372 /kaggle/working/TrainData/img/image_1333.h5 /kaggle/working/TrainData/mask/mask_1333.h5
# 373 /kaggle/working/TrainData/img/image_1334.h5 /kaggle/working/TrainData/mask/mask_1334.h5
# 374 /kaggle/working/TrainData/img/image_1335.h5 /kaggle/working/TrainData/mask/mask_1335.h5
# 375 /kaggle/working/TrainData/img/image_1336.h5 /kaggle/working/TrainData/mask/mask_1336.h5
# 376 /kaggle/working/TrainData/img/image_1337.h5 /kaggle/working/TrainData/mask/mask_1337.h5
# 377 /kaggle/working/TrainData/img/image_1338.h5 /kaggle/working/TrainData/mask/mask_1338.h5
# 378 /kaggle/working/TrainData/img/image_1339.h5 /kaggle/working/TrainData/mask/mask_1339.h5
# 379 /kaggle/working/TrainData/img/image_134.h5 /kaggle/working/TrainData/mask/mask_134.h5
# 380 /kaggle/working/TrainData/img/image_1340.h5 /kaggle/working/TrainData/mask/mask_1340.h5
# 381 /kaggle/working/TrainData/img/image_1341.h5 /kaggle/working/TrainData/mask/mask_1341.h5
# 382 /kaggle/working/TrainData/img/image_1342.h5 /kaggle/working/TrainData/mask/mask_1342.h5
# 383 /kaggle/working/TrainData/img/image_1343.h5 /kaggle/working/TrainData/mask/mask_1343.h5
# 384 /kaggle/working/TrainData/img/image_1344.h5 /kaggle/working/TrainData/mask/mask_1344.h5
# 385 /kaggle/working/TrainData/img/image_1345.h5 /kaggle/working/TrainData/mask/mask_1345.h5
# 386 /kaggle/working/TrainData/img/image_1346.h5 /kaggle/working/TrainData/mask/mask_1346.h5
# 387 /kaggle/working/TrainData/img/image_1347.h5 /kaggle/working/TrainData/mask/mask_1347.h5
# 388 /kaggle/working/TrainData/img/image_1348.h5 /kaggle/working/TrainData/mask/mask_1348.h5
# 389 /kaggle/working/TrainData/img/image_1349.h5 /kaggle/working/TrainData/mask/mask_1349.h5
# 390 /kaggle/working/TrainData/img/image_135.h5 /kaggle/working/TrainData/mask/mask_135.h5
# 391 /kaggle/working/TrainData/img/image_1350.h5 /kaggle/working/TrainData/mask/mask_1350.h5
# 392 /kaggle/working/TrainData/img/image_1351.h5 /kaggle/working/TrainData/mask/mask_1351.h5
# 393 /kaggle/working/TrainData/img/image_1352.h5 /kaggle/working/TrainData/mask/mask_1352.h5
# 394 /kaggle/working/TrainData/img/image_1353.h5 /kaggle/working/TrainData/mask/mask_1353.h5
# 395 /kaggle/working/TrainData/img/image_1354.h5 /kaggle/working/TrainData/mask/mask_1354.h5
# 396 /kaggle/working/TrainData/img/image_1355.h5 /kaggle/working/TrainData/mask/mask_1355.h5
# 397 /kaggle/working/TrainData/img/image_1356.h5 /kaggle/working/TrainData/mask/mask_1356.h5
# 398 /kaggle/working/TrainData/img/image_1357.h5 /kaggle/working/TrainData/mask/mask_1357.h5
# 399 /kaggle/working/TrainData/img/image_1358.h5 /kaggle/working/TrainData/mask/mask_1358.h5
# 400 /kaggle/working/TrainData/img/image_1359.h5 /kaggle/working/TrainData/mask/mask_1359.h5
# 401 /kaggle/working/TrainData/img/image_136.h5 /kaggle/working/TrainData/mask/mask_136.h5
# 402 /kaggle/working/TrainData/img/image_1360.h5 /kaggle/working/TrainData/mask/mask_1360.h5
# 403 /kaggle/working/TrainData/img/image_1361.h5 /kaggle/working/TrainData/mask/mask_1361.h5
# 404 /kaggle/working/TrainData/img/image_1362.h5 /kaggle/working/TrainData/mask/mask_1362.h5
# 405 /kaggle/working/TrainData/img/image_1363.h5 /kaggle/working/TrainData/mask/mask_1363.h5
# 406 /kaggle/working/TrainData/img/image_1364.h5 /kaggle/working/TrainData/mask/mask_1364.h5
# 407 /kaggle/working/TrainData/img/image_1365.h5 /kaggle/working/TrainData/mask/mask_1365.h5
# 408 /kaggle/working/TrainData/img/image_1366.h5 /kaggle/working/TrainData/mask/mask_1366.h5
# 409 /kaggle/working/TrainData/img/image_1367.h5 /kaggle/working/TrainData/mask/mask_1367.h5
# 410 /kaggle/working/TrainData/img/image_1368.h5 /kaggle/working/TrainData/mask/mask_1368.h5
# 411 /kaggle/working/TrainData/img/image_1369.h5 /kaggle/working/TrainData/mask/mask_1369.h5
# 412 /kaggle/working/TrainData/img/image_137.h5 /kaggle/working/TrainData/mask/mask_137.h5
# 413 /kaggle/working/TrainData/img/image_1370.h5 /kaggle/working/TrainData/mask/mask_1370.h5
# 414 /kaggle/working/TrainData/img/image_1371.h5 /kaggle/working/TrainData/mask/mask_1371.h5
# 415 /kaggle/working/TrainData/img/image_1372.h5 /kaggle/working/TrainData/mask/mask_1372.h5
# 416 /kaggle/working/TrainData/img/image_1373.h5 /kaggle/working/TrainData/mask/mask_1373.h5
# 417 /kaggle/working/TrainData/img/image_1374.h5 /kaggle/working/TrainData/mask/mask_1374.h5
# 418 /kaggle/working/TrainData/img/image_1375.h5 /kaggle/working/TrainData/mask/mask_1375.h5
# 419 /kaggle/working/TrainData/img/image_1376.h5 /kaggle/working/TrainData/mask/mask_1376.h5
# 420 /kaggle/working/TrainData/img/image_1377.h5 /kaggle/working/TrainData/mask/mask_1377.h5
# 421 /kaggle/working/TrainData/img/image_1378.h5 /kaggle/working/TrainData/mask/mask_1378.h5
# 422 /kaggle/working/TrainData/img/image_1379.h5 /kaggle/working/TrainData/mask/mask_1379.h5
# 423 /kaggle/working/TrainData/img/image_138.h5 /kaggle/working/TrainData/mask/mask_138.h5
# 424 /kaggle/working/TrainData/img/image_1380.h5 /kaggle/working/TrainData/mask/mask_1380.h5
# 425 /kaggle/working/TrainData/img/image_1381.h5 /kaggle/working/TrainData/mask/mask_1381.h5
# 426 /kaggle/working/TrainData/img/image_1382.h5 /kaggle/working/TrainData/mask/mask_1382.h5
# 427 /kaggle/working/TrainData/img/image_1383.h5 /kaggle/working/TrainData/mask/mask_1383.h5
# 428 /kaggle/working/TrainData/img/image_1384.h5 /kaggle/working/TrainData/mask/mask_1384.h5
# 429 /kaggle/working/TrainData/img/image_1385.h5 /kaggle/working/TrainData/mask/mask_1385.h5
# 430 /kaggle/working/TrainData/img/image_1386.h5 /kaggle/working/TrainData/mask/mask_1386.h5
# 431 /kaggle/working/TrainData/img/image_1387.h5 /kaggle/working/TrainData/mask/mask_1387.h5
# 432 /kaggle/working/TrainData/img/image_1388.h5 /kaggle/working/TrainData/mask/mask_1388.h5
# 433 /kaggle/working/TrainData/img/image_1389.h5 /kaggle/working/TrainData/mask/mask_1389.h5
# 434 /kaggle/working/TrainData/img/image_139.h5 /kaggle/working/TrainData/mask/mask_139.h5
# 435 /kaggle/working/TrainData/img/image_1390.h5 /kaggle/working/TrainData/mask/mask_1390.h5
# 436 /kaggle/working/TrainData/img/image_1391.h5 /kaggle/working/TrainData/mask/mask_1391.h5
# 437 /kaggle/working/TrainData/img/image_1392.h5 /kaggle/working/TrainData/mask/mask_1392.h5
# 438 /kaggle/working/TrainData/img/image_1393.h5 /kaggle/working/TrainData/mask/mask_1393.h5
# 439 /kaggle/working/TrainData/img/image_1394.h5 /kaggle/working/TrainData/mask/mask_1394.h5
# 440 /kaggle/working/TrainData/img/image_1395.h5 /kaggle/working/TrainData/mask/mask_1395.h5
# 441 /kaggle/working/TrainData/img/image_1396.h5 /kaggle/working/TrainData/mask/mask_1396.h5
# 442 /kaggle/working/TrainData/img/image_1397.h5 /kaggle/working/TrainData/mask/mask_1397.h5
# 443 /kaggle/working/TrainData/img/image_1398.h5 /kaggle/working/TrainData/mask/mask_1398.h5
# 444 /kaggle/working/TrainData/img/image_1399.h5 /kaggle/working/TrainData/mask/mask_1399.h5
# 445 /kaggle/working/TrainData/img/image_14.h5 /kaggle/working/TrainData/mask/mask_14.h5
# 446 /kaggle/working/TrainData/img/image_140.h5 /kaggle/working/TrainData/mask/mask_140.h5
# 447 /kaggle/working/TrainData/img/image_1400.h5 /kaggle/working/TrainData/mask/mask_1400.h5
# 448 /kaggle/working/TrainData/img/image_1401.h5 /kaggle/working/TrainData/mask/mask_1401.h5
# 449 /kaggle/working/TrainData/img/image_1402.h5 /kaggle/working/TrainData/mask/mask_1402.h5
# 450 /kaggle/working/TrainData/img/image_1403.h5 /kaggle/working/TrainData/mask/mask_1403.h5
# 451 /kaggle/working/TrainData/img/image_1404.h5 /kaggle/working/TrainData/mask/mask_1404.h5
# 452 /kaggle/working/TrainData/img/image_1405.h5 /kaggle/working/TrainData/mask/mask_1405.h5
# 453 /kaggle/working/TrainData/img/image_1406.h5 /kaggle/working/TrainData/mask/mask_1406.h5
# 454 /kaggle/working/TrainData/img/image_1407.h5 /kaggle/working/TrainData/mask/mask_1407.h5
# 455 /kaggle/working/TrainData/img/image_1408.h5 /kaggle/working/TrainData/mask/mask_1408.h5
# 456 /kaggle/working/TrainData/img/image_1409.h5 /kaggle/working/TrainData/mask/mask_1409.h5
# 457 /kaggle/working/TrainData/img/image_141.h5 /kaggle/working/TrainData/mask/mask_141.h5
# 458 /kaggle/working/TrainData/img/image_1410.h5 /kaggle/working/TrainData/mask/mask_1410.h5
# 459 /kaggle/working/TrainData/img/image_1411.h5 /kaggle/working/TrainData/mask/mask_1411.h5
# 460 /kaggle/working/TrainData/img/image_1412.h5 /kaggle/working/TrainData/mask/mask_1412.h5
# 461 /kaggle/working/TrainData/img/image_1413.h5 /kaggle/working/TrainData/mask/mask_1413.h5
# 462 /kaggle/working/TrainData/img/image_1414.h5 /kaggle/working/TrainData/mask/mask_1414.h5
# 463 /kaggle/working/TrainData/img/image_1415.h5 /kaggle/working/TrainData/mask/mask_1415.h5
# 464 /kaggle/working/TrainData/img/image_1416.h5 /kaggle/working/TrainData/mask/mask_1416.h5
# 465 /kaggle/working/TrainData/img/image_1417.h5 /kaggle/working/TrainData/mask/mask_1417.h5
# 466 /kaggle/working/TrainData/img/image_1418.h5 /kaggle/working/TrainData/mask/mask_1418.h5
# 467 /kaggle/working/TrainData/img/image_1419.h5 /kaggle/working/TrainData/mask/mask_1419.h5
# 468 /kaggle/working/TrainData/img/image_142.h5 /kaggle/working/TrainData/mask/mask_142.h5
# 469 /kaggle/working/TrainData/img/image_1420.h5 /kaggle/working/TrainData/mask/mask_1420.h5
# 470 /kaggle/working/TrainData/img/image_1421.h5 /kaggle/working/TrainData/mask/mask_1421.h5
# 471 /kaggle/working/TrainData/img/image_1422.h5 /kaggle/working/TrainData/mask/mask_1422.h5
# 472 /kaggle/working/TrainData/img/image_1423.h5 /kaggle/working/TrainData/mask/mask_1423.h5
# 473 /kaggle/working/TrainData/img/image_1424.h5 /kaggle/working/TrainData/mask/mask_1424.h5
# 474 /kaggle/working/TrainData/img/image_1425.h5 /kaggle/working/TrainData/mask/mask_1425.h5
# 475 /kaggle/working/TrainData/img/image_1426.h5 /kaggle/working/TrainData/mask/mask_1426.h5
# 476 /kaggle/working/TrainData/img/image_1427.h5 /kaggle/working/TrainData/mask/mask_1427.h5
# 477 /kaggle/working/TrainData/img/image_1428.h5 /kaggle/working/TrainData/mask/mask_1428.h5
# 478 /kaggle/working/TrainData/img/image_1429.h5 /kaggle/working/TrainData/mask/mask_1429.h5
# 479 /kaggle/working/TrainData/img/image_143.h5 /kaggle/working/TrainData/mask/mask_143.h5
# 480 /kaggle/working/TrainData/img/image_1430.h5 /kaggle/working/TrainData/mask/mask_1430.h5
# 481 /kaggle/working/TrainData/img/image_1431.h5 /kaggle/working/TrainData/mask/mask_1431.h5
# 482 /kaggle/working/TrainData/img/image_1432.h5 /kaggle/working/TrainData/mask/mask_1432.h5
# 483 /kaggle/working/TrainData/img/image_1433.h5 /kaggle/working/TrainData/mask/mask_1433.h5
# 484 /kaggle/working/TrainData/img/image_1434.h5 /kaggle/working/TrainData/mask/mask_1434.h5
# 485 /kaggle/working/TrainData/img/image_1435.h5 /kaggle/working/TrainData/mask/mask_1435.h5
# 486 /kaggle/working/TrainData/img/image_1436.h5 /kaggle/working/TrainData/mask/mask_1436.h5
# 487 /kaggle/working/TrainData/img/image_1437.h5 /kaggle/working/TrainData/mask/mask_1437.h5
# 488 /kaggle/working/TrainData/img/image_1438.h5 /kaggle/working/TrainData/mask/mask_1438.h5
# 489 /kaggle/working/TrainData/img/image_1439.h5 /kaggle/working/TrainData/mask/mask_1439.h5
# 490 /kaggle/working/TrainData/img/image_144.h5 /kaggle/working/TrainData/mask/mask_144.h5
# 491 /kaggle/working/TrainData/img/image_1440.h5 /kaggle/working/TrainData/mask/mask_1440.h5
# 492 /kaggle/working/TrainData/img/image_1441.h5 /kaggle/working/TrainData/mask/mask_1441.h5
# 493 /kaggle/working/TrainData/img/image_1442.h5 /kaggle/working/TrainData/mask/mask_1442.h5
# 494 /kaggle/working/TrainData/img/image_1443.h5 /kaggle/working/TrainData/mask/mask_1443.h5
# 495 /kaggle/working/TrainData/img/image_1444.h5 /kaggle/working/TrainData/mask/mask_1444.h5
# 496 /kaggle/working/TrainData/img/image_1445.h5 /kaggle/working/TrainData/mask/mask_1445.h5
# 497 /kaggle/working/TrainData/img/image_1446.h5 /kaggle/working/TrainData/mask/mask_1446.h5
# 498 /kaggle/working/TrainData/img/image_1447.h5 /kaggle/working/TrainData/mask/mask_1447.h5
# 499 /kaggle/working/TrainData/img/image_1448.h5 /kaggle/working/TrainData/mask/mask_1448.h5
# 500 /kaggle/working/TrainData/img/image_1449.h5 /kaggle/working/TrainData/mask/mask_1449.h5
# 501 /kaggle/working/TrainData/img/image_145.h5 /kaggle/working/TrainData/mask/mask_145.h5
# 502 /kaggle/working/TrainData/img/image_1450.h5 /kaggle/working/TrainData/mask/mask_1450.h5
# 503 /kaggle/working/TrainData/img/image_1451.h5 /kaggle/working/TrainData/mask/mask_1451.h5
# 504 /kaggle/working/TrainData/img/image_1452.h5 /kaggle/working/TrainData/mask/mask_1452.h5
# 505 /kaggle/working/TrainData/img/image_1453.h5 /kaggle/working/TrainData/mask/mask_1453.h5
# 506 /kaggle/working/TrainData/img/image_1454.h5 /kaggle/working/TrainData/mask/mask_1454.h5
# 507 /kaggle/working/TrainData/img/image_1455.h5 /kaggle/working/TrainData/mask/mask_1455.h5
# 508 /kaggle/working/TrainData/img/image_1456.h5 /kaggle/working/TrainData/mask/mask_1456.h5
# 509 /kaggle/working/TrainData/img/image_1457.h5 /kaggle/working/TrainData/mask/mask_1457.h5
# 510 /kaggle/working/TrainData/img/image_1458.h5 /kaggle/working/TrainData/mask/mask_1458.h5
# 511 /kaggle/working/TrainData/img/image_1459.h5 /kaggle/working/TrainData/mask/mask_1459.h5
# 512 /kaggle/working/TrainData/img/image_146.h5 /kaggle/working/TrainData/mask/mask_146.h5
# 513 /kaggle/working/TrainData/img/image_1460.h5 /kaggle/working/TrainData/mask/mask_1460.h5
# 514 /kaggle/working/TrainData/img/image_1461.h5 /kaggle/working/TrainData/mask/mask_1461.h5
# 515 /kaggle/working/TrainData/img/image_1462.h5 /kaggle/working/TrainData/mask/mask_1462.h5
# 516 /kaggle/working/TrainData/img/image_1463.h5 /kaggle/working/TrainData/mask/mask_1463.h5
# 517 /kaggle/working/TrainData/img/image_1464.h5 /kaggle/working/TrainData/mask/mask_1464.h5
# 518 /kaggle/working/TrainData/img/image_1465.h5 /kaggle/working/TrainData/mask/mask_1465.h5
# 519 /kaggle/working/TrainData/img/image_1466.h5 /kaggle/working/TrainData/mask/mask_1466.h5
# 520 /kaggle/working/TrainData/img/image_1467.h5 /kaggle/working/TrainData/mask/mask_1467.h5
# 521 /kaggle/working/TrainData/img/image_1468.h5 /kaggle/working/TrainData/mask/mask_1468.h5
# 522 /kaggle/working/TrainData/img/image_1469.h5 /kaggle/working/TrainData/mask/mask_1469.h5
# 523 /kaggle/working/TrainData/img/image_147.h5 /kaggle/working/TrainData/mask/mask_147.h5
# ...
# 3623 /kaggle/working/TrainData/img/image_840.h5 /kaggle/working/TrainData/mask/mask_840.h5
# 3624 /kaggle/working/TrainData/img/image_841.h5 /kaggle/working/TrainData/mask/mask_841.h5
# 3625 /kaggle/working/TrainData/img/image_842.h5 /kaggle/working/TrainData/mask/mask_842.h5
# 3626 /kaggle/working/TrainData/img/image_843.h5 /kaggle/working/TrainData/mask/mask_843.h5
# 3627 /kaggle/working/TrainData/img/image_844.h5 /kaggle/working/TrainData/mask/mask_844.h5
# 3628 /kaggle/working/TrainData/img/image_845.h5 /kaggle/working/TrainData/mask/mask_845.h5
# 3629 /kaggle/working/TrainData/img/image_846.h5 /kaggle/working/TrainData/mask/mask_846.h5
# 3630 /kaggle/working/TrainData/img/image_847.h5 /kaggle/working/TrainData/mask/mask_847.h5
# 3631 /kaggle/working/TrainData/img/image_848.h5 /kaggle/working/TrainData/mask/mask_848.h5
# 3632 /kaggle/working/TrainData/img/image_849.h5 /kaggle/working/TrainData/mask/mask_849.h5
# 3633 /kaggle/working/TrainData/img/image_85.h5 /kaggle/working/TrainData/mask/mask_85.h5
# 3634 /kaggle/working/TrainData/img/image_850.h5 /kaggle/working/TrainData/mask/mask_850.h5
# 3635 /kaggle/working/TrainData/img/image_851.h5 /kaggle/working/TrainData/mask/mask_851.h5
# 3636 /kaggle/working/TrainData/img/image_852.h5 /kaggle/working/TrainData/mask/mask_852.h5
# 3637 /kaggle/working/TrainData/img/image_853.h5 /kaggle/working/TrainData/mask/mask_853.h5
# 3638 /kaggle/working/TrainData/img/image_854.h5 /kaggle/working/TrainData/mask/mask_854.h5
# 3639 /kaggle/working/TrainData/img/image_855.h5 /kaggle/working/TrainData/mask/mask_855.h5
# 3640 /kaggle/working/TrainData/img/image_856.h5 /kaggle/working/TrainData/mask/mask_856.h5
# 3641 /kaggle/working/TrainData/img/image_857.h5 /kaggle/working/TrainData/mask/mask_857.h5
# 3642 /kaggle/working/TrainData/img/image_858.h5 /kaggle/working/TrainData/mask/mask_858.h5
# 3643 /kaggle/working/TrainData/img/image_859.h5 /kaggle/working/TrainData/mask/mask_859.h5
# 3644 /kaggle/working/TrainData/img/image_86.h5 /kaggle/working/TrainData/mask/mask_86.h5
# 3645 /kaggle/working/TrainData/img/image_860.h5 /kaggle/working/TrainData/mask/mask_860.h5
# 3646 /kaggle/working/TrainData/img/image_861.h5 /kaggle/working/TrainData/mask/mask_861.h5
# 3647 /kaggle/working/TrainData/img/image_862.h5 /kaggle/working/TrainData/mask/mask_862.h5
# 3648 /kaggle/working/TrainData/img/image_863.h5 /kaggle/working/TrainData/mask/mask_863.h5
# 3649 /kaggle/working/TrainData/img/image_864.h5 /kaggle/working/TrainData/mask/mask_864.h5
# 3650 /kaggle/working/TrainData/img/image_865.h5 /kaggle/working/TrainData/mask/mask_865.h5
# 3651 /kaggle/working/TrainData/img/image_866.h5 /kaggle/working/TrainData/mask/mask_866.h5
# 3652 /kaggle/working/TrainData/img/image_867.h5 /kaggle/working/TrainData/mask/mask_867.h5
# 3653 /kaggle/working/TrainData/img/image_868.h5 /kaggle/working/TrainData/mask/mask_868.h5
# 3654 /kaggle/working/TrainData/img/image_869.h5 /kaggle/working/TrainData/mask/mask_869.h5
# 3655 /kaggle/working/TrainData/img/image_87.h5 /kaggle/working/TrainData/mask/mask_87.h5
# 3656 /kaggle/working/TrainData/img/image_870.h5 /kaggle/working/TrainData/mask/mask_870.h5
# 3657 /kaggle/working/TrainData/img/image_871.h5 /kaggle/working/TrainData/mask/mask_871.h5
# 3658 /kaggle/working/TrainData/img/image_872.h5 /kaggle/working/TrainData/mask/mask_872.h5
# 3659 /kaggle/working/TrainData/img/image_873.h5 /kaggle/working/TrainData/mask/mask_873.h5
# 3660 /kaggle/working/TrainData/img/image_874.h5 /kaggle/working/TrainData/mask/mask_874.h5
# 3661 /kaggle/working/TrainData/img/image_875.h5 /kaggle/working/TrainData/mask/mask_875.h5
# 3662 /kaggle/working/TrainData/img/image_876.h5 /kaggle/working/TrainData/mask/mask_876.h5
# 3663 /kaggle/working/TrainData/img/image_877.h5 /kaggle/working/TrainData/mask/mask_877.h5
# 3664 /kaggle/working/TrainData/img/image_878.h5 /kaggle/working/TrainData/mask/mask_878.h5
# 3665 /kaggle/working/TrainData/img/image_879.h5 /kaggle/working/TrainData/mask/mask_879.h5
# 3666 /kaggle/working/TrainData/img/image_88.h5 /kaggle/working/TrainData/mask/mask_88.h5
# 3667 /kaggle/working/TrainData/img/image_880.h5 /kaggle/working/TrainData/mask/mask_880.h5
# 3668 /kaggle/working/TrainData/img/image_881.h5 /kaggle/working/TrainData/mask/mask_881.h5
# 3669 /kaggle/working/TrainData/img/image_882.h5 /kaggle/working/TrainData/mask/mask_882.h5
# 3670 /kaggle/working/TrainData/img/image_883.h5 /kaggle/working/TrainData/mask/mask_883.h5
# 3671 /kaggle/working/TrainData/img/image_884.h5 /kaggle/working/TrainData/mask/mask_884.h5
# 3672 /kaggle/working/TrainData/img/image_885.h5 /kaggle/working/TrainData/mask/mask_885.h5
# 3673 /kaggle/working/TrainData/img/image_886.h5 /kaggle/working/TrainData/mask/mask_886.h5
# 3674 /kaggle/working/TrainData/img/image_887.h5 /kaggle/working/TrainData/mask/mask_887.h5
# 3675 /kaggle/working/TrainData/img/image_888.h5 /kaggle/working/TrainData/mask/mask_888.h5
# 3676 /kaggle/working/TrainData/img/image_889.h5 /kaggle/working/TrainData/mask/mask_889.h5
# 3677 /kaggle/working/TrainData/img/image_89.h5 /kaggle/working/TrainData/mask/mask_89.h5
# 3678 /kaggle/working/TrainData/img/image_890.h5 /kaggle/working/TrainData/mask/mask_890.h5
# 3679 /kaggle/working/TrainData/img/image_891.h5 /kaggle/working/TrainData/mask/mask_891.h5
# 3680 /kaggle/working/TrainData/img/image_892.h5 /kaggle/working/TrainData/mask/mask_892.h5
# 3681 /kaggle/working/TrainData/img/image_893.h5 /kaggle/working/TrainData/mask/mask_893.h5
# 3682 /kaggle/working/TrainData/img/image_894.h5 /kaggle/working/TrainData/mask/mask_894.h5
# 3683 /kaggle/working/TrainData/img/image_895.h5 /kaggle/working/TrainData/mask/mask_895.h5
# 3684 /kaggle/working/TrainData/img/image_896.h5 /kaggle/working/TrainData/mask/mask_896.h5
# 3685 /kaggle/working/TrainData/img/image_897.h5 /kaggle/working/TrainData/mask/mask_897.h5
# 3686 /kaggle/working/TrainData/img/image_898.h5 /kaggle/working/TrainData/mask/mask_898.h5
# 3687 /kaggle/working/TrainData/img/image_899.h5 /kaggle/working/TrainData/mask/mask_899.h5
# 3688 /kaggle/working/TrainData/img/image_9.h5 /kaggle/working/TrainData/mask/mask_9.h5
# 3689 /kaggle/working/TrainData/img/image_90.h5 /kaggle/working/TrainData/mask/mask_90.h5
# 3690 /kaggle/working/TrainData/img/image_900.h5 /kaggle/working/TrainData/mask/mask_900.h5
# 3691 /kaggle/working/TrainData/img/image_901.h5 /kaggle/working/TrainData/mask/mask_901.h5
# 3692 /kaggle/working/TrainData/img/image_902.h5 /kaggle/working/TrainData/mask/mask_902.h5
# 3693 /kaggle/working/TrainData/img/image_903.h5 /kaggle/working/TrainData/mask/mask_903.h5
# 3694 /kaggle/working/TrainData/img/image_904.h5 /kaggle/working/TrainData/mask/mask_904.h5
# 3695 /kaggle/working/TrainData/img/image_905.h5 /kaggle/working/TrainData/mask/mask_905.h5
# 3696 /kaggle/working/TrainData/img/image_906.h5 /kaggle/working/TrainData/mask/mask_906.h5
# 3697 /kaggle/working/TrainData/img/image_907.h5 /kaggle/working/TrainData/mask/mask_907.h5
# 3698 /kaggle/working/TrainData/img/image_908.h5 /kaggle/working/TrainData/mask/mask_908.h5
# 3699 /kaggle/working/TrainData/img/image_909.h5 /kaggle/working/TrainData/mask/mask_909.h5
# 3700 /kaggle/working/TrainData/img/image_91.h5 /kaggle/working/TrainData/mask/mask_91.h5
# 3701 /kaggle/working/TrainData/img/image_910.h5 /kaggle/working/TrainData/mask/mask_910.h5
# 3702 /kaggle/working/TrainData/img/image_911.h5 /kaggle/working/TrainData/mask/mask_911.h5
# 3703 /kaggle/working/TrainData/img/image_912.h5 /kaggle/working/TrainData/mask/mask_912.h5
# 3704 /kaggle/working/TrainData/img/image_913.h5 /kaggle/working/TrainData/mask/mask_913.h5
# 3705 /kaggle/working/TrainData/img/image_914.h5 /kaggle/working/TrainData/mask/mask_914.h5
# 3706 /kaggle/working/TrainData/img/image_915.h5 /kaggle/working/TrainData/mask/mask_915.h5
# 3707 /kaggle/working/TrainData/img/image_916.h5 /kaggle/working/TrainData/mask/mask_916.h5
# 3708 /kaggle/working/TrainData/img/image_917.h5 /kaggle/working/TrainData/mask/mask_917.h5
# 3709 /kaggle/working/TrainData/img/image_918.h5 /kaggle/working/TrainData/mask/mask_918.h5
# 3710 /kaggle/working/TrainData/img/image_919.h5 /kaggle/working/TrainData/mask/mask_919.h5
# 3711 /kaggle/working/TrainData/img/image_92.h5 /kaggle/working/TrainData/mask/mask_92.h5
# 3712 /kaggle/working/TrainData/img/image_920.h5 /kaggle/working/TrainData/mask/mask_920.h5
# 3713 /kaggle/working/TrainData/img/image_921.h5 /kaggle/working/TrainData/mask/mask_921.h5
# 3714 /kaggle/working/TrainData/img/image_922.h5 /kaggle/working/TrainData/mask/mask_922.h5
# 3715 /kaggle/working/TrainData/img/image_923.h5 /kaggle/working/TrainData/mask/mask_923.h5
# 3716 /kaggle/working/TrainData/img/image_924.h5 /kaggle/working/TrainData/mask/mask_924.h5
# 3717 /kaggle/working/TrainData/img/image_925.h5 /kaggle/working/TrainData/mask/mask_925.h5
# 3718 /kaggle/working/TrainData/img/image_926.h5 /kaggle/working/TrainData/mask/mask_926.h5
# 3719 /kaggle/working/TrainData/img/image_927.h5 /kaggle/working/TrainData/mask/mask_927.h5
# 3720 /kaggle/working/TrainData/img/image_928.h5 /kaggle/working/TrainData/mask/mask_928.h5
# 3721 /kaggle/working/TrainData/img/image_929.h5 /kaggle/working/TrainData/mask/mask_929.h5
# 3722 /kaggle/working/TrainData/img/image_93.h5 /kaggle/working/TrainData/mask/mask_93.h5
# 3723 /kaggle/working/TrainData/img/image_930.h5 /kaggle/working/TrainData/mask/mask_930.h5
# 3724 /kaggle/working/TrainData/img/image_931.h5 /kaggle/working/TrainData/mask/mask_931.h5
# 3725 /kaggle/working/TrainData/img/image_932.h5 /kaggle/working/TrainData/mask/mask_932.h5
# 3726 /kaggle/working/TrainData/img/image_933.h5 /kaggle/working/TrainData/mask/mask_933.h5
# 3727 /kaggle/working/TrainData/img/image_934.h5 /kaggle/working/TrainData/mask/mask_934.h5
# 3728 /kaggle/working/TrainData/img/image_935.h5 /kaggle/working/TrainData/mask/mask_935.h5
# 3729 /kaggle/working/TrainData/img/image_936.h5 /kaggle/working/TrainData/mask/mask_936.h5
# 3730 /kaggle/working/TrainData/img/image_937.h5 /kaggle/working/TrainData/mask/mask_937.h5
# 3731 /kaggle/working/TrainData/img/image_938.h5 /kaggle/working/TrainData/mask/mask_938.h5
# 3732 /kaggle/working/TrainData/img/image_939.h5 /kaggle/working/TrainData/mask/mask_939.h5
# 3733 /kaggle/working/TrainData/img/image_94.h5 /kaggle/working/TrainData/mask/mask_94.h5
# 3734 /kaggle/working/TrainData/img/image_940.h5 /kaggle/working/TrainData/mask/mask_940.h5
# 3735 /kaggle/working/TrainData/img/image_941.h5 /kaggle/working/TrainData/mask/mask_941.h5
# 3736 /kaggle/working/TrainData/img/image_942.h5 /kaggle/working/TrainData/mask/mask_942.h5
# 3737 /kaggle/working/TrainData/img/image_943.h5 /kaggle/working/TrainData/mask/mask_943.h5
# 3738 /kaggle/working/TrainData/img/image_944.h5 /kaggle/working/TrainData/mask/mask_944.h5
# 3739 /kaggle/working/TrainData/img/image_945.h5 /kaggle/working/TrainData/mask/mask_945.h5
# 3740 /kaggle/working/TrainData/img/image_946.h5 /kaggle/working/TrainData/mask/mask_946.h5
# 3741 /kaggle/working/TrainData/img/image_947.h5 /kaggle/working/TrainData/mask/mask_947.h5
# 3742 /kaggle/working/TrainData/img/image_948.h5 /kaggle/working/TrainData/mask/mask_948.h5
# 3743 /kaggle/working/TrainData/img/image_949.h5 /kaggle/working/TrainData/mask/mask_949.h5
# 3744 /kaggle/working/TrainData/img/image_95.h5 /kaggle/working/TrainData/mask/mask_95.h5
# 3745 /kaggle/working/TrainData/img/image_950.h5 /kaggle/working/TrainData/mask/mask_950.h5
# 3746 /kaggle/working/TrainData/img/image_951.h5 /kaggle/working/TrainData/mask/mask_951.h5
# 3747 /kaggle/working/TrainData/img/image_952.h5 /kaggle/working/TrainData/mask/mask_952.h5
# 3748 /kaggle/working/TrainData/img/image_953.h5 /kaggle/working/TrainData/mask/mask_953.h5
# 3749 /kaggle/working/TrainData/img/image_954.h5 /kaggle/working/TrainData/mask/mask_954.h5
# 3750 /kaggle/working/TrainData/img/image_955.h5 /kaggle/working/TrainData/mask/mask_955.h5
# 3751 /kaggle/working/TrainData/img/image_956.h5 /kaggle/working/TrainData/mask/mask_956.h5
# 3752 /kaggle/working/TrainData/img/image_957.h5 /kaggle/working/TrainData/mask/mask_957.h5
# 3753 /kaggle/working/TrainData/img/image_958.h5 /kaggle/working/TrainData/mask/mask_958.h5
# 3754 /kaggle/working/TrainData/img/image_959.h5 /kaggle/working/TrainData/mask/mask_959.h5
# 3755 /kaggle/working/TrainData/img/image_96.h5 /kaggle/working/TrainData/mask/mask_96.h5
# 3756 /kaggle/working/TrainData/img/image_960.h5 /kaggle/working/TrainData/mask/mask_960.h5
# 3757 /kaggle/working/TrainData/img/image_961.h5 /kaggle/working/TrainData/mask/mask_961.h5
# 3758 /kaggle/working/TrainData/img/image_962.h5 /kaggle/working/TrainData/mask/mask_962.h5
# 3759 /kaggle/working/TrainData/img/image_963.h5 /kaggle/working/TrainData/mask/mask_963.h5
# 3760 /kaggle/working/TrainData/img/image_964.h5 /kaggle/working/TrainData/mask/mask_964.h5
# 3761 /kaggle/working/TrainData/img/image_965.h5 /kaggle/working/TrainData/mask/mask_965.h5
# 3762 /kaggle/working/TrainData/img/image_966.h5 /kaggle/working/TrainData/mask/mask_966.h5
# 3763 /kaggle/working/TrainData/img/image_967.h5 /kaggle/working/TrainData/mask/mask_967.h5
# 3764 /kaggle/working/TrainData/img/image_968.h5 /kaggle/working/TrainData/mask/mask_968.h5
# 3765 /kaggle/working/TrainData/img/image_969.h5 /kaggle/working/TrainData/mask/mask_969.h5
# 3766 /kaggle/working/TrainData/img/image_97.h5 /kaggle/working/TrainData/mask/mask_97.h5
# 3767 /kaggle/working/TrainData/img/image_970.h5 /kaggle/working/TrainData/mask/mask_970.h5
# 3768 /kaggle/working/TrainData/img/image_971.h5 /kaggle/working/TrainData/mask/mask_971.h5
# 3769 /kaggle/working/TrainData/img/image_972.h5 /kaggle/working/TrainData/mask/mask_972.h5
# 3770 /kaggle/working/TrainData/img/image_973.h5 /kaggle/working/TrainData/mask/mask_973.h5
# 3771 /kaggle/working/TrainData/img/image_974.h5 /kaggle/working/TrainData/mask/mask_974.h5
# 3772 /kaggle/working/TrainData/img/image_975.h5 /kaggle/working/TrainData/mask/mask_975.h5
# 3773 /kaggle/working/TrainData/img/image_976.h5 /kaggle/working/TrainData/mask/mask_976.h5
# 3774 /kaggle/working/TrainData/img/image_977.h5 /kaggle/working/TrainData/mask/mask_977.h5
# 3775 /kaggle/working/TrainData/img/image_978.h5 /kaggle/working/TrainData/mask/mask_978.h5
# 3776 /kaggle/working/TrainData/img/image_979.h5 /kaggle/working/TrainData/mask/mask_979.h5
# 3777 /kaggle/working/TrainData/img/image_98.h5 /kaggle/working/TrainData/mask/mask_98.h5
# 3778 /kaggle/working/TrainData/img/image_980.h5 /kaggle/working/TrainData/mask/mask_980.h5
# 3779 /kaggle/working/TrainData/img/image_981.h5 /kaggle/working/TrainData/mask/mask_981.h5
# 3780 /kaggle/working/TrainData/img/image_982.h5 /kaggle/working/TrainData/mask/mask_982.h5
# 3781 /kaggle/working/TrainData/img/image_983.h5 /kaggle/working/TrainData/mask/mask_983.h5
# 3782 /kaggle/working/TrainData/img/image_984.h5 /kaggle/working/TrainData/mask/mask_984.h5
# 3783 /kaggle/working/TrainData/img/image_985.h5 /kaggle/working/TrainData/mask/mask_985.h5
# 3784 /kaggle/working/TrainData/img/image_986.h5 /kaggle/working/TrainData/mask/mask_986.h5
# 3785 /kaggle/working/TrainData/img/image_987.h5 /kaggle/working/TrainData/mask/mask_987.h5
# 3786 /kaggle/working/TrainData/img/image_988.h5 /kaggle/working/TrainData/mask/mask_988.h5
# 3787 /kaggle/working/TrainData/img/image_989.h5 /kaggle/working/TrainData/mask/mask_989.h5
# 3788 /kaggle/working/TrainData/img/image_99.h5 /kaggle/working/TrainData/mask/mask_99.h5
# 3789 /kaggle/working/TrainData/img/image_990.h5 /kaggle/working/TrainData/mask/mask_990.h5
# 3790 /kaggle/working/TrainData/img/image_991.h5 /kaggle/working/TrainData/mask/mask_991.h5
# 3791 /kaggle/working/TrainData/img/image_992.h5 /kaggle/working/TrainData/mask/mask_992.h5
# 3792 /kaggle/working/TrainData/img/image_993.h5 /kaggle/working/TrainData/mask/mask_993.h5
# 3793 /kaggle/working/TrainData/img/image_994.h5 /kaggle/working/TrainData/mask/mask_994.h5
# 3794 /kaggle/working/TrainData/img/image_995.h5 /kaggle/working/TrainData/mask/mask_995.h5
# 3795 /kaggle/working/TrainData/img/image_996.h5 /kaggle/working/TrainData/mask/mask_996.h5
# 3796 /kaggle/working/TrainData/img/image_997.h5 /kaggle/working/TrainData/mask/mask_997.h5
# 3797 /kaggle/working/TrainData/img/image_998.h5 /kaggle/working/TrainData/mask/mask_998.h5
# 3798 /kaggle/working/TrainData/img/image_999.h5 /kaggle/working/TrainData/mask/mask_999.h5

# %%
# TRAIN_XX_n = TRAIN_XX / TRAIN_XX.max()
TRAIN_XX[np.isnan(TRAIN_XX)] = 0.000001
print(TRAIN_XX.min(), TRAIN_XX.max(), TRAIN_YY.min(), TRAIN_YY.max())
# Out:
# -1.0 1.0 0.0 1.0

# %%
from sklearn.model_selection import train_test_split

# Split the data
x_train, x_valid, y_train, y_valid = train_test_split(TRAIN_XX, TRAIN_YY, test_size=0.2, shuffle= True)

# %%
x_train.shape, y_train.shape
# Out:
# ((3039, 128, 128, 6), (3039, 128, 128, 1))

# %%
# to release some memory, delete the unnecessary variable
del TRAIN_XX
del TRAIN_YY
del all_train
del all_mask

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
from sklearn.metrics import precision_score, recall_score
import torch.nn.functional as F
# UNet model definition
class UNet(nn.Module):
    def __init__(self, in_channels=1, out_channels=1):
        super(UNet, self).__init__()
        self.conv1 = self.double_conv(in_channels, 16)
        self.conv2 = self.double_conv(16, 32)
        self.conv3 = self.double_conv(32, 64)
        self.conv4 = self.double_conv(64, 128)
        self.conv5 = self.double_conv(128, 256)
        self.upconv1 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.conv6 = self.double_conv(256, 128)
        self.upconv2 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.conv7 = self.double_conv(128, 64)
        self.upconv3 = nn.ConvTranspose2d(64, 32, kernel_size=2, stride=2)
        self.conv8 = self.double_conv(64, 32)
        self.upconv4 = nn.ConvTranspose2d(32, 16, kernel_size=2, stride=2)
        self.conv9 = self.double_conv(32, 16)
        self.conv10 = nn.Conv2d(16, out_channels, kernel_size=1)

    def double_conv(self, in_channels, out_channels):
        return nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        c1 = self.conv1(x)
        p1 = F.max_pool2d(c1, kernel_size=2, stride=2)
        c2 = self.conv2(p1)
        p2 = F.max_pool2d(c2, kernel_size=2, stride=2)
        c3 = self.conv3(p2)
        p3 = F.max_pool2d(c3, kernel_size=2, stride=2)
        c4 = self.conv4(p3)
        p4 = F.max_pool2d(c4, kernel_size=2, stride=2)
        c5 = self.conv5(p4)
        u6 = self.upconv1(c5)
        u6 = torch.cat([u6, c4], dim=1)
        c6 = self.conv6(u6)
        u7 = self.upconv2(c6)
        u7 = torch.cat([u7, c3], dim=1)
        c7 = self.conv7(u7)
        u8 = self.upconv3(c7)
        u8 = torch.cat([u8, c2], dim=1)
        c8 = self.conv8(u8)
        u9 = self.upconv4(c8)
        u9 = torch.cat([u9, c1], dim=1)
        c9 = self.conv9(u9)
        outputs = self.conv10(c9)
        outputs = torch.sigmoid(outputs)
        return outputs

# %%
# Dice loss function
class DiceLoss(nn.Module):
    def __init__(self, smooth=1):
        super(DiceLoss, self).__init__()
        self.smooth = smooth

    def forward(self, y_true, y_pred):
        y_true_f = y_true.view(-1)
        y_pred_f = y_pred.view(-1)
        intersection = torch.sum(y_true_f * y_pred_f)
        return 1 - (2. * intersection + self.smooth) / (torch.sum(y_true_f) + torch.sum(y_pred_f) + self.smooth)

# Function to calculate Dice coefficient
def dice_coefficient(y_true, y_pred):
    smooth = 1e-6
    y_true_f = y_true.view(-1)
    y_pred_f = y_pred.view(-1)
    intersection = torch.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (torch.sum(y_true_f) + torch.sum(y_pred_f) + smooth)

# Function to calculate accuracy
def accuracy(y_true, y_pred):
    y_pred = y_pred > 0.5
    correct = (y_true == y_pred).sum().float()
    return correct / y_true.numel()

# Function to calculate precision and recall
def precision_recall(y_true, y_pred):
    y_true = y_true.cpu().numpy().astype(int).flatten()
    y_pred = (y_pred > 0.5).cpu().numpy().astype(int).flatten()
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    return precision, recall


# Assuming x_train, y_train, x_valid, y_valid are already loaded as numpy arrays or tensors
x_train = x_train[:, :, :, :6]
x_valid = x_valid[:, :, :, :6]
x_train_tensor = torch.tensor(x_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
x_valid_tensor = torch.tensor(x_valid, dtype=torch.float32)
y_valid_tensor = torch.tensor(y_valid, dtype=torch.float32)

# Normalize the input data
x_train_tensor = (x_train_tensor - x_train_tensor.mean()) / x_train_tensor.std()
x_valid_tensor = (x_valid_tensor - x_valid_tensor.mean()) / x_valid_tensor.std()

# Create DataLoader for training and validation sets
train_dataset = TensorDataset(x_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
valid_dataset = TensorDataset(x_valid_tensor, y_valid_tensor)
valid_loader = DataLoader(valid_dataset, batch_size=16, shuffle=False)

# %%
# Initialize UNet model
model = UNet(in_channels=6, out_channels=1)

# Define optimizer and loss function
optimizer = optim.Adam(model.parameters(), lr=1e-3)  # Adjusted learning rate
criterion = DiceLoss()  # Using Dice loss

# %%
# Training function
def train(model, train_loader, valid_loader, optimizer, criterion, epochs=100, device='cuda'):
    best_valid_f1 = -np.inf
    for epoch in range(epochs):
        # Training
        model.train()
        train_loss = 0.0
        train_dice = 0.0
        train_accuracy = 0.0
        train_precision = 0.0
        train_recall = 0.0

        for inputs, targets in train_loader:
            inputs = inputs.permute(0, 3, 1, 2).to(device)  # Permute to (batch, channels, height, width)
            targets = targets.permute(0, 3, 1, 2).to(device)  # Permute to (batch, channels, height, width)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * inputs.size(0)
            train_dice += dice_coefficient(targets, torch.sigmoid(outputs)).item() * inputs.size(0)
            train_accuracy += accuracy(targets, outputs).item() * inputs.size(0)
            precision, recall = precision_recall(targets, outputs)
            train_precision += precision * inputs.size(0)
            train_recall += recall * inputs.size(0)

        train_loss /= len(train_loader.dataset)
        train_dice /= len(train_loader.dataset)
        train_accuracy /= len(train_loader.dataset)
        train_precision /= len(train_loader.dataset)
        train_recall /= len(train_loader.dataset)

        # Validation
        model.eval()
        valid_loss = 0.0
        valid_dice = 0.0
        valid_accuracy = 0.0
        valid_precision = 0.0
        valid_recall = 0.0

        with torch.no_grad():
            for inputs, targets in valid_loader:
                inputs = inputs.permute(0, 3, 1, 2).to(device)  # Permute to (batch, channels, height, width)
                targets = targets.permute(0, 3, 1, 2).to(device)  # Permute to (batch, channels, height, width)
                outputs = model(inputs)
                loss = criterion(outputs, targets)
                valid_loss += loss.item() * inputs.size(0)
                valid_dice += dice_coefficient(targets, torch.sigmoid(outputs)).item() * inputs.size(0)
                valid_accuracy += accuracy(targets, outputs).item() * inputs.size(0)
                precision, recall = precision_recall(targets, outputs)
                valid_precision += precision * inputs.size(0)
                valid_recall += recall * inputs.size(0)

        valid_loss /= len(valid_loader.dataset)
        valid_dice /= len(valid_loader.dataset)
        valid_accuracy /= len(valid_loader.dataset)
        valid_precision /= len(valid_loader.dataset)
        valid_recall /= len(valid_loader.dataset)

        print(f'Epoch {epoch+1}/{epochs}, '
              f'Train Loss: {train_loss:.4f}, Train Dice: {train_dice:.4f}, Train Acc: {train_accuracy:.4f}, '
              f'Train Precision: {train_precision:.4f}, Train Recall: {train_recall:.4f}, '
              f'Valid Loss: {valid_loss:.4f}, Valid Dice: {valid_dice:.4f}, Valid Acc: {valid_accuracy:.4f}, '
              f'Valid Precision: {valid_precision:.4f}, Valid Recall: {valid_recall:.4f}')

        # Save the best model based on validation F1-score
        valid_f1 = 2 * (valid_precision * valid_recall) / (valid_precision + valid_recall)
        if valid_f1 > best_valid_f1:
            best_valid_f1 = valid_f1
            torch.save(model.state_dict(), 'landslide_unet_best_model.pth')
            print(f'Saved Best Model with Valid F1: {valid_f1:.4f}')

# Train the model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
train(model, train_loader, valid_loader, optimizer, criterion, epochs=100, device=device)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 1/100, Train Loss: 0.5818, Train Dice: 0.0558, Train Acc: 0.9483, Train Precision: 0.4153, Train Recall: 0.6065, Valid Loss: 0.4764, Valid Dice: 0.0487, Valid Acc: 0.9793, Valid Precision: 0.4956, Valid Recall: 0.6062
# Saved Best Model with Valid F1: 0.5454
# Epoch 2/100, Train Loss: 0.4200, Train Dice: 0.0579, Train Acc: 0.9791, Train Precision: 0.5725, Train Recall: 0.6357, Valid Loss: 0.4813, Valid Dice: 0.0470, Valid Acc: 0.9820, Valid Precision: 0.5875, Valid Recall: 0.4985
# Epoch 3/100, Train Loss: 0.4042, Train Dice: 0.0583, Train Acc: 0.9807, Train Precision: 0.5929, Train Recall: 0.6427, Valid Loss: 0.4963, Valid Dice: 0.0453, Valid Acc: 0.9847, Valid Precision: 0.6909, Valid Recall: 0.4099
# Epoch 4/100, Train Loss: 0.3699, Train Dice: 0.0587, Train Acc: 0.9826, Train Precision: 0.6290, Train Recall: 0.6652, Valid Loss: 0.3984, Valid Dice: 0.0504, Valid Acc: 0.9827, Valid Precision: 0.5300, Valid Recall: 0.7198
# Saved Best Model with Valid F1: 0.6105
# Epoch 5/100, Train Loss: 0.3396, Train Dice: 0.0590, Train Acc: 0.9841, Train Precision: 0.6623, Train Recall: 0.6814, Valid Loss: 0.3814, Valid Dice: 0.0499, Valid Acc: 0.9848, Valid Precision: 0.5860, Valid Recall: 0.6756
# Saved Best Model with Valid F1: 0.6276
# Epoch 6/100, Train Loss: 0.3319, Train Dice: 0.0593, Train Acc: 0.9848, Train Precision: 0.6693, Train Recall: 0.6906, Valid Loss: 0.3770, Valid Dice: 0.0487, Valid Acc: 0.9867, Valid Precision: 0.6621, Valid Recall: 0.5995
# Saved Best Model with Valid F1: 0.6292
# Epoch 7/100, Train Loss: 0.3265, Train Dice: 0.0593, Train Acc: 0.9853, Train Precision: 0.6723, Train Recall: 0.6927, Valid Loss: 0.4059, Valid Dice: 0.0479, Valid Acc: 0.9862, Valid Precision: 0.6686, Valid Recall: 0.5509
# Epoch 8/100, Train Loss: 0.3204, Train Dice: 0.0594, Train Acc: 0.9852, Train Precision: 0.6753, Train Recall: 0.7034, Valid Loss: 0.3576, Valid Dice: 0.0496, Valid Acc: 0.9866, Valid Precision: 0.6443, Valid Recall: 0.6551
# Saved Best Model with Valid F1: 0.6496
# Epoch 9/100, Train Loss: 0.3237, Train Dice: 0.0593, Train Acc: 0.9852, Train Precision: 0.6756, Train Recall: 0.7002, Valid Loss: 0.3635, Valid Dice: 0.0494, Valid Acc: 0.9865, Valid Precision: 0.6414, Valid Recall: 0.6463
# Epoch 10/100, Train Loss: 0.3155, Train Dice: 0.0595, Train Acc: 0.9857, Train Precision: 0.6869, Train Recall: 0.7003, Valid Loss: 0.3684, Valid Dice: 0.0487, Valid Acc: 0.9872, Valid Precision: 0.6833, Valid Recall: 0.5986
# Epoch 11/100, Train Loss: 0.3206, Train Dice: 0.0592, Train Acc: 0.9855, Train Precision: 0.6814, Train Recall: 0.7000, Valid Loss: 0.3843, Valid Dice: 0.0481, Valid Acc: 0.9871, Valid Precision: 0.6986, Valid Recall: 0.5589
# Epoch 12/100, Train Loss: 0.3077, Train Dice: 0.0597, Train Acc: 0.9858, Train Precision: 0.6865, Train Recall: 0.7148, Valid Loss: 0.3533, Valid Dice: 0.0494, Valid Acc: 0.9871, Valid Precision: 0.6625, Valid Recall: 0.6443
# Saved Best Model with Valid F1: 0.6533
# Epoch 13/100, Train Loss: 0.3157, Train Dice: 0.0595, Train Acc: 0.9856, Train Precision: 0.6844, Train Recall: 0.7026, Valid Loss: 0.3687, Valid Dice: 0.0485, Valid Acc: 0.9874, Valid Precision: 0.6964, Valid Recall: 0.5877
# Epoch 14/100, Train Loss: 0.3102, Train Dice: 0.0598, Train Acc: 0.9857, Train Precision: 0.6878, Train Recall: 0.7122, Valid Loss: 0.3815, Valid Dice: 0.0483, Valid Acc: 0.9870, Valid Precision: 0.6906, Valid Recall: 0.5731
# Epoch 15/100, Train Loss: 0.3024, Train Dice: 0.0598, Train Acc: 0.9862, Train Precision: 0.6967, Train Recall: 0.7142, Valid Loss: 0.3486, Valid Dice: 0.0496, Valid Acc: 0.9873, Valid Precision: 0.6645, Valid Recall: 0.6490
# Saved Best Model with Valid F1: 0.6567
# Epoch 16/100, Train Loss: 0.3002, Train Dice: 0.0597, Train Acc: 0.9860, Train Precision: 0.7000, Train Recall: 0.7143, Valid Loss: 0.3524, Valid Dice: 0.0503, Valid Acc: 0.9860, Valid Precision: 0.6124, Valid Recall: 0.7040
# Epoch 17/100, Train Loss: 0.3069, Train Dice: 0.0597, Train Acc: 0.9862, Train Precision: 0.6947, Train Recall: 0.7104, Valid Loss: 0.3477, Valid Dice: 0.0508, Valid Acc: 0.9857, Valid Precision: 0.6015, Valid Recall: 0.7302
# Saved Best Model with Valid F1: 0.6597
# Epoch 18/100, Train Loss: 0.3002, Train Dice: 0.0598, Train Acc: 0.9866, Train Precision: 0.6968, Train Recall: 0.7181, Valid Loss: 0.3412, Valid Dice: 0.0498, Valid Acc: 0.9874, Valid Precision: 0.6664, Valid Recall: 0.6635
# Saved Best Model with Valid F1: 0.6649
# Epoch 19/100, Train Loss: 0.3019, Train Dice: 0.0597, Train Acc: 0.9861, Train Precision: 0.6993, Train Recall: 0.7158, Valid Loss: 0.3516, Valid Dice: 0.0491, Valid Acc: 0.9877, Valid Precision: 0.6949, Valid Recall: 0.6165
# Epoch 20/100, Train Loss: 0.2946, Train Dice: 0.0598, Train Acc: 0.9866, Train Precision: 0.7051, Train Recall: 0.7200, Valid Loss: 0.3569, Valid Dice: 0.0509, Valid Acc: 0.9850, Valid Precision: 0.5794, Valid Recall: 0.7428
# Epoch 21/100, Train Loss: 0.3047, Train Dice: 0.0598, Train Acc: 0.9860, Train Precision: 0.6929, Train Recall: 0.7187, Valid Loss: 0.3636, Valid Dice: 0.0492, Valid Acc: 0.9866, Valid Precision: 0.6532, Valid Recall: 0.6367
# Epoch 22/100, Train Loss: 0.2992, Train Dice: 0.0597, Train Acc: 0.9868, Train Precision: 0.6998, Train Recall: 0.7182, Valid Loss: 0.3449, Valid Dice: 0.0491, Valid Acc: 0.9879, Valid Precision: 0.7001, Valid Recall: 0.6259
# Epoch 23/100, Train Loss: 0.2888, Train Dice: 0.0599, Train Acc: 0.9869, Train Precision: 0.7115, Train Recall: 0.7228, Valid Loss: 0.3451, Valid Dice: 0.0501, Valid Acc: 0.9868, Valid Precision: 0.6423, Valid Recall: 0.6833
# Epoch 24/100, Train Loss: 0.2851, Train Dice: 0.0600, Train Acc: 0.9869, Train Precision: 0.7124, Train Recall: 0.7312, Valid Loss: 0.3741, Valid Dice: 0.0478, Valid Acc: 0.9880, Valid Precision: 0.7541, Valid Recall: 0.5419
# Epoch 25/100, Train Loss: 0.2982, Train Dice: 0.0598, Train Acc: 0.9867, Train Precision: 0.7058, Train Recall: 0.7154, Valid Loss: 0.4108, Valid Dice: 0.0470, Valid Acc: 0.9875, Valid Precision: 0.7617, Valid Recall: 0.4870
# Epoch 26/100, Train Loss: 0.2913, Train Dice: 0.0599, Train Acc: 0.9868, Train Precision: 0.7048, Train Recall: 0.7251, Valid Loss: 0.3613, Valid Dice: 0.0482, Valid Acc: 0.9882, Valid Precision: 0.7494, Valid Recall: 0.5635
# Epoch 27/100, Train Loss: 0.2882, Train Dice: 0.0599, Train Acc: 0.9872, Train Precision: 0.7159, Train Recall: 0.7207, Valid Loss: 0.3340, Valid Dice: 0.0495, Valid Acc: 0.9879, Valid Precision: 0.6905, Valid Recall: 0.6517
# Saved Best Model with Valid F1: 0.6705
# Epoch 28/100, Train Loss: 0.2806, Train Dice: 0.0602, Train Acc: 0.9873, Train Precision: 0.7168, Train Recall: 0.7323, Valid Loss: 0.3265, Valid Dice: 0.0500, Valid Acc: 0.9879, Valid Precision: 0.6797, Valid Recall: 0.6755
# Saved Best Model with Valid F1: 0.6776
# Epoch 29/100, Train Loss: 0.2902, Train Dice: 0.0601, Train Acc: 0.9865, Train Precision: 0.7082, Train Recall: 0.7287, Valid Loss: 0.3484, Valid Dice: 0.0487, Valid Acc: 0.9882, Valid Precision: 0.7239, Valid Recall: 0.5995
# Epoch 30/100, Train Loss: 0.2801, Train Dice: 0.0600, Train Acc: 0.9873, Train Precision: 0.7203, Train Recall: 0.7300, Valid Loss: 0.3496, Valid Dice: 0.0486, Valid Acc: 0.9882, Valid Precision: 0.7295, Valid Recall: 0.5938
# Epoch 31/100, Train Loss: 0.2804, Train Dice: 0.0602, Train Acc: 0.9874, Train Precision: 0.7157, Train Recall: 0.7345, Valid Loss: 0.3294, Valid Dice: 0.0499, Valid Acc: 0.9879, Valid Precision: 0.6791, Valid Recall: 0.6715
# Epoch 32/100, Train Loss: 0.2753, Train Dice: 0.0602, Train Acc: 0.9874, Train Precision: 0.7242, Train Recall: 0.7364, Valid Loss: 0.3398, Valid Dice: 0.0503, Valid Acc: 0.9869, Valid Precision: 0.6428, Valid Recall: 0.6912
# Epoch 33/100, Train Loss: 0.2732, Train Dice: 0.0603, Train Acc: 0.9875, Train Precision: 0.7236, Train Recall: 0.7391, Valid Loss: 0.3317, Valid Dice: 0.0494, Valid Acc: 0.9883, Valid Precision: 0.7103, Valid Recall: 0.6386
# Epoch 34/100, Train Loss: 0.2705, Train Dice: 0.0604, Train Acc: 0.9876, Train Precision: 0.7312, Train Recall: 0.7383, Valid Loss: 0.3341, Valid Dice: 0.0496, Valid Acc: 0.9879, Valid Precision: 0.6908, Valid Recall: 0.6515
# Epoch 35/100, Train Loss: 0.2697, Train Dice: 0.0602, Train Acc: 0.9877, Train Precision: 0.7338, Train Recall: 0.7374, Valid Loss: 0.3371, Valid Dice: 0.0501, Valid Acc: 0.9871, Valid Precision: 0.6470, Valid Recall: 0.6892
# Epoch 36/100, Train Loss: 0.2847, Train Dice: 0.0600, Train Acc: 0.9872, Train Precision: 0.7168, Train Recall: 0.7290, Valid Loss: 0.3742, Valid Dice: 0.0477, Valid Acc: 0.9882, Valid Precision: 0.7700, Valid Recall: 0.5340
# Epoch 37/100, Train Loss: 0.2762, Train Dice: 0.0602, Train Acc: 0.9875, Train Precision: 0.7241, Train Recall: 0.7364, Valid Loss: 0.3242, Valid Dice: 0.0502, Valid Acc: 0.9877, Valid Precision: 0.6661, Valid Recall: 0.6959
# Saved Best Model with Valid F1: 0.6807
# Epoch 38/100, Train Loss: 0.2744, Train Dice: 0.0602, Train Acc: 0.9877, Train Precision: 0.7224, Train Recall: 0.7380, Valid Loss: 0.3452, Valid Dice: 0.0491, Valid Acc: 0.9880, Valid Precision: 0.7093, Valid Recall: 0.6169
# Epoch 39/100, Train Loss: 0.2733, Train Dice: 0.0601, Train Acc: 0.9878, Train Precision: 0.7278, Train Recall: 0.7346, Valid Loss: 0.3289, Valid Dice: 0.0500, Valid Acc: 0.9878, Valid Precision: 0.6743, Valid Recall: 0.6770
# Epoch 40/100, Train Loss: 0.2685, Train Dice: 0.0603, Train Acc: 0.9879, Train Precision: 0.7296, Train Recall: 0.7413, Valid Loss: 0.3342, Valid Dice: 0.0501, Valid Acc: 0.9874, Valid Precision: 0.6597, Valid Recall: 0.6838
# Epoch 41/100, Train Loss: 0.2710, Train Dice: 0.0603, Train Acc: 0.9877, Train Precision: 0.7271, Train Recall: 0.7404, Valid Loss: 0.3248, Valid Dice: 0.0501, Valid Acc: 0.9877, Valid Precision: 0.6726, Valid Recall: 0.6875
# Epoch 42/100, Train Loss: 0.2717, Train Dice: 0.0603, Train Acc: 0.9879, Train Precision: 0.7258, Train Recall: 0.7409, Valid Loss: 0.3341, Valid Dice: 0.0510, Valid Acc: 0.9862, Valid Precision: 0.6082, Valid Recall: 0.7503
# Epoch 43/100, Train Loss: 0.2749, Train Dice: 0.0602, Train Acc: 0.9876, Train Precision: 0.7242, Train Recall: 0.7390, Valid Loss: 0.3469, Valid Dice: 0.0487, Valid Acc: 0.9883, Valid Precision: 0.7338, Valid Recall: 0.5945
# Epoch 44/100, Train Loss: 0.2670, Train Dice: 0.0603, Train Acc: 0.9880, Train Precision: 0.7358, Train Recall: 0.7374, Valid Loss: 0.3516, Valid Dice: 0.0485, Valid Acc: 0.9883, Valid Precision: 0.7386, Valid Recall: 0.5848
# Epoch 45/100, Train Loss: 0.2638, Train Dice: 0.0604, Train Acc: 0.9881, Train Precision: 0.7358, Train Recall: 0.7454, Valid Loss: 0.3235, Valid Dice: 0.0498, Valid Acc: 0.9881, Valid Precision: 0.6925, Valid Recall: 0.6690
# Epoch 46/100, Train Loss: 0.2592, Train Dice: 0.0605, Train Acc: 0.9882, Train Precision: 0.7369, Train Recall: 0.7517, Valid Loss: 0.3378, Valid Dice: 0.0492, Valid Acc: 0.9882, Valid Precision: 0.7181, Valid Recall: 0.6227
# Epoch 47/100, Train Loss: 0.2568, Train Dice: 0.0604, Train Acc: 0.9884, Train Precision: 0.7490, Train Recall: 0.7466, Valid Loss: 0.3263, Valid Dice: 0.0497, Valid Acc: 0.9882, Valid Precision: 0.6961, Valid Recall: 0.6616
# Epoch 48/100, Train Loss: 0.2581, Train Dice: 0.0605, Train Acc: 0.9884, Train Precision: 0.7453, Train Recall: 0.7466, Valid Loss: 0.3295, Valid Dice: 0.0499, Valid Acc: 0.9877, Valid Precision: 0.6768, Valid Recall: 0.6740
# Epoch 49/100, Train Loss: 0.2555, Train Dice: 0.0605, Train Acc: 0.9884, Train Precision: 0.7462, Train Recall: 0.7491, Valid Loss: 0.3307, Valid Dice: 0.0502, Valid Acc: 0.9871, Valid Precision: 0.6502, Valid Recall: 0.6993
# Epoch 50/100, Train Loss: 0.2595, Train Dice: 0.0606, Train Acc: 0.9883, Train Precision: 0.7379, Train Recall: 0.7508, Valid Loss: 0.3331, Valid Dice: 0.0511, Valid Acc: 0.9862, Valid Precision: 0.6091, Valid Recall: 0.7521
# Epoch 51/100, Train Loss: 0.2523, Train Dice: 0.0605, Train Acc: 0.9886, Train Precision: 0.7522, Train Recall: 0.7505, Valid Loss: 0.3251, Valid Dice: 0.0497, Valid Acc: 0.9883, Valid Precision: 0.7065, Valid Recall: 0.6538
# Epoch 52/100, Train Loss: 0.2538, Train Dice: 0.0605, Train Acc: 0.9886, Train Precision: 0.7449, Train Recall: 0.7543, Valid Loss: 0.3292, Valid Dice: 0.0496, Valid Acc: 0.9881, Valid Precision: 0.6985, Valid Recall: 0.6542
# Epoch 53/100, Train Loss: 0.2511, Train Dice: 0.0605, Train Acc: 0.9887, Train Precision: 0.7511, Train Recall: 0.7529, Valid Loss: 0.3200, Valid Dice: 0.0504, Valid Acc: 0.9878, Valid Precision: 0.6662, Valid Recall: 0.7028
# Saved Best Model with Valid F1: 0.6840
# Epoch 54/100, Train Loss: 0.2578, Train Dice: 0.0605, Train Acc: 0.9885, Train Precision: 0.7432, Train Recall: 0.7504, Valid Loss: 0.3287, Valid Dice: 0.0495, Valid Acc: 0.9882, Valid Precision: 0.7075, Valid Recall: 0.6458
# Epoch 55/100, Train Loss: 0.2531, Train Dice: 0.0607, Train Acc: 0.9887, Train Precision: 0.7497, Train Recall: 0.7515, Valid Loss: 0.3576, Valid Dice: 0.0485, Valid Acc: 0.9881, Valid Precision: 0.7378, Valid Recall: 0.5765
